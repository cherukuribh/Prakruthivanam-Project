# %%
#Exploratory Data Analysis
#importing libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#read the dataset
Billwise_sales = pd.read_csv("Billwise-Sales-Report-2019-2022.csv")
Billwise_sales.head(10)
# Out:
#       TIME        DATE       BILL_NO                  CONSUMER_NAME  \
# 0  09:12pm  30/09/2022  AA/2223/7106                   Praveen Kphb
# 1  09:11pm  30/09/2022  AA/2223/7105                   Praveen Kphb
# 2  08:43pm  30/09/2022  AA/2223/7104                          Guest
# 3  08:15pm  30/09/2022  AA/2223/7103       Venkata Ratnam 6th Phase
# 4  08:08pm  30/09/2022  AA/2223/7102  Raghavendra Vivekananda Nagar
# 5  07:46pm  30/09/2022  AA/2223/7101                      Venugopal
# 6  07:08pm  30/09/2022  AA/2223/7100                     P S N Raju
# 7  06:41pm  30/09/2022  AA/2223/7099                 Kiran Kompalli
# 8  06:06pm  30/09/2022  AA/2223/7098                           Raju
# 9  05:46pm  30/09/2022  AA/2223/7097                      Jayashree
#
#    Taxable_Amount_0%  Taxable_Amount_5%  Taxable_Amount_12%  \
# 0                0.0              0.000               0.000
# 1              225.0            219.048               0.000
# 2                0.0              0.000               0.000
# 3                0.0            791.398               0.000
# 4                0.0            380.952             410.714
# 5                0.0            200.000               0.000
# 6              130.0              0.000               0.000
# 7                0.0              0.000               0.000
# 8                0.0            190.476               0.000
# 9                0.0            123.810               0.000
#
#    Taxable_Amount_18%      CGST      SGST  TOTAL_TAX_AMOUNT  TOTAL_BILL_VALUE  \
# 0            9745.763   877.119   877.119          1754.237           11500.0
# 1             177.966    21.493    21.493            42.986             665.0
# 2           10169.492   915.254   915.254          1830.508           12000.0
# 3              75.451    26.576    26.576            53.151             920.0
# 4               0.000    34.167    34.167            68.333             860.0
# 5               0.000     5.000     5.000            10.000             210.0
# 6               0.000     0.000     0.000             0.000             130.0
# 7           12033.898  1083.051  1083.051          2166.102           14200.0
# 8             262.712    28.406    28.406            56.812             510.0
# 9               0.000     3.095     3.095             6.190             130.0
#
#    TOTAL_NOOF_ITEMS_PURCHASED PAYMENT_TYPE ONLINE/OFFLINE
# 0                           1        Paytm         Online
# 1                           6        Paytm         Online
# 2                           1        Paytm         Online
# 3                           5         Cash        Offline
# 4                           7         Card         Online
# 5                           2        Paytm         Online
# 6                           1        Paytm         Online
# 7                           2        Paytm         Online
# 8                           2        Paytm         Online
# 9                           1         Cash        Offline

# %%
Billwise_sales.shape
# Out:
# (51737, 15)

# %%
Billwise_sales.describe()
# Out:
#        Taxable_Amount_0%  Taxable_Amount_5%  Taxable_Amount_12%  \
# count       51737.000000       51737.000000        51737.000000
# mean          335.173185         387.028248           49.460116
# std           959.921250         944.927242          217.516244
# min        -14400.000000       -6019.048000        -4616.071000
# 25%             0.000000           0.000000            0.000000
# 50%            60.000000          52.381000            0.000000
# 75%           300.000000         419.048000            0.000000
# max         45375.000000       74628.571000         8006.062000
#
#        Taxable_Amount_18%          CGST          SGST  TOTAL_TAX_AMOUNT  \
# count        51737.000000  51737.000000  51737.000000      51737.000000
# mean           181.829712     29.007994     29.007994         58.015968
# std           1108.342299    105.129639    105.129639        210.259261
# min         -58474.576000  -5262.712000  -5262.712000     -10525.424000
# 25%              0.000000      0.000000      0.000000          0.000000
# 50%              0.000000      5.119000      5.119000         10.238000
# 75%              0.000000     25.238000     25.238000         50.476000
# max          58474.576000   5262.712000   5262.712000      10525.424000
#
#        TOTAL_BILL_VALUE  TOTAL_NOOF_ITEMS_PURCHASED
# count      51737.000000                51737.000000
# mean        1011.586396                    4.215030
# std         1903.779929                    4.369999
# min       -69000.000000                  -22.000000
# 25%          195.000000                    1.000000
# 50%          470.000000                    3.000000
# 75%         1100.000000                    6.000000
# max        78360.000000                   61.000000

# %%
Billwise_sales.dtypes
# Out:
# TIME                           object
# DATE                           object
# BILL_NO                        object
# CONSUMER_NAME                  object
# Taxable_Amount_0%             float64
# Taxable_Amount_5%             float64
# Taxable_Amount_12%            float64
# Taxable_Amount_18%            float64
# CGST                          float64
# SGST                          float64
# TOTAL_TAX_AMOUNT              float64
# TOTAL_BILL_VALUE              float64
# TOTAL_NOOF_ITEMS_PURCHASED      int64
# PAYMENT_TYPE                   object
# ONLINE/OFFLINE                 object
# dtype: object

# %%
Billwise_sales.isnull().sum()
# Out:
# TIME                          0
# DATE                          0
# BILL_NO                       0
# CONSUMER_NAME                 0
# Taxable_Amount_0%             0
# Taxable_Amount_5%             0
# Taxable_Amount_12%            0
# Taxable_Amount_18%            0
# CGST                          0
# SGST                          0
# TOTAL_TAX_AMOUNT              0
# TOTAL_BILL_VALUE              0
# TOTAL_NOOF_ITEMS_PURCHASED    0
# PAYMENT_TYPE                  0
# ONLINE/OFFLINE                0
# dtype: int64

# %%
Billwise_sales = pd.read_csv("Billwise-Sales-Report-2019-2022.csv")
Billwise_sales['DATE'] = pd.to_datetime(Billwise_sales['DATE'], format = "%d/%m/%Y")
Billwise_sales['TIME'] = pd.to_datetime(Billwise_sales['TIME'],format="%I:%M%p").dt.strftime('%H:%M')
Billwise_sales['month_year'] = pd.to_datetime(Billwise_sales['DATE']).dt.to_period('M')
Billwise_sales['Hour'] = pd.to_datetime(Billwise_sales['TIME']).dt.hour
Billwise_sales
# Out:
#         TIME       DATE       BILL_NO                  CONSUMER_NAME  \
# 0      21:12 2022-09-30  AA/2223/7106                   Praveen Kphb
# 1      21:11 2022-09-30  AA/2223/7105                   Praveen Kphb
# 2      20:43 2022-09-30  AA/2223/7104                          Guest
# 3      20:15 2022-09-30  AA/2223/7103       Venkata Ratnam 6th Phase
# 4      20:08 2022-09-30  AA/2223/7102  Raghavendra Vivekananda Nagar
# ...      ...        ...           ...                            ...
# 51732  13:55 2019-01-01     A-A000128                         ravi l
# 51733  13:48 2019-01-01     A-A000127                         balaji
# 51734  13:40 2019-01-01     A-A000126                           ramu
# 51735  13:37 2019-01-01     A-A000125                          ratna
# 51736  13:29 2019-01-01     A-A000124              Ramesh Hydernagar
#
#        Taxable_Amount_0%  Taxable_Amount_5%  Taxable_Amount_12%  \
# 0                    0.0              0.000               0.000
# 1                  225.0            219.048               0.000
# 2                    0.0              0.000               0.000
# 3                    0.0            791.398               0.000
# 4                    0.0            380.952             410.714
# ...                  ...                ...                 ...
# 51732              205.0              0.000               0.000
# 51733              880.0              0.000               0.000
# 51734              225.0              0.000               0.000
# 51735              390.0              0.000               0.000
# 51736              770.0              0.000               0.000
#
#        Taxable_Amount_18%     CGST     SGST  TOTAL_TAX_AMOUNT  \
# 0                9745.763  877.119  877.119          1754.237
# 1                 177.966   21.493   21.493            42.986
# 2               10169.492  915.254  915.254          1830.508
# 3                  75.451   26.576   26.576            53.151
# 4                   0.000   34.167   34.167            68.333
# ...                   ...      ...      ...               ...
# 51732               0.000    0.000    0.000             0.000
# 51733               0.000    0.000    0.000             0.000
# 51734               0.000    0.000    0.000             0.000
# 51735               0.000    0.000    0.000             0.000
# 51736               0.000    0.000    0.000             0.000
#
#        TOTAL_BILL_VALUE  TOTAL_NOOF_ITEMS_PURCHASED PAYMENT_TYPE  \
# 0               11500.0                           1        Paytm
# 1                 665.0                           6        Paytm
# 2               12000.0                           1        Paytm
# 3                 920.0                           5         Cash
# 4                 860.0                           7         Card
# ...                 ...                         ...          ...
# 51732             205.0                           4         Card
# 51733             880.0                           7       Credit
# 51734             225.0                           1         Card
# 51735             390.0                           3         Cash
# 51736             770.0                           5         Card
#
#       ONLINE/OFFLINE month_year  Hour
# 0             Online    2022-09    21
# 1             Online    2022-09    21
# 2             Online    2022-09    20
# 3            Offline    2022-09    20
# 4             Online    2022-09    20
# ...              ...        ...   ...
# 51732         Online    2019-01    13
# 51733         Online    2019-01    13
# 51734         Online    2019-01    13
# 51735        Offline    2019-01    13
# 51736         Online    2019-01    13
#
# [51737 rows x 17 columns]

# %%
Billwise_sales['Dayofweek']= Billwise_sales['DATE'].dt.day_name()
Billwise_sales
# Out:
#         TIME       DATE       BILL_NO                  CONSUMER_NAME  \
# 0      21:12 2022-09-30  AA/2223/7106                   Praveen Kphb
# 1      21:11 2022-09-30  AA/2223/7105                   Praveen Kphb
# 2      20:43 2022-09-30  AA/2223/7104                          Guest
# 3      20:15 2022-09-30  AA/2223/7103       Venkata Ratnam 6th Phase
# 4      20:08 2022-09-30  AA/2223/7102  Raghavendra Vivekananda Nagar
# ...      ...        ...           ...                            ...
# 51732  13:55 2019-01-01     A-A000128                         ravi l
# 51733  13:48 2019-01-01     A-A000127                         balaji
# 51734  13:40 2019-01-01     A-A000126                           ramu
# 51735  13:37 2019-01-01     A-A000125                          ratna
# 51736  13:29 2019-01-01     A-A000124              Ramesh Hydernagar
#
#        Taxable_Amount_0%  Taxable_Amount_5%  Taxable_Amount_12%  \
# 0                    0.0              0.000               0.000
# 1                  225.0            219.048               0.000
# 2                    0.0              0.000               0.000
# 3                    0.0            791.398               0.000
# 4                    0.0            380.952             410.714
# ...                  ...                ...                 ...
# 51732              205.0              0.000               0.000
# 51733              880.0              0.000               0.000
# 51734              225.0              0.000               0.000
# 51735              390.0              0.000               0.000
# 51736              770.0              0.000               0.000
#
#        Taxable_Amount_18%     CGST     SGST  TOTAL_TAX_AMOUNT  \
# 0                9745.763  877.119  877.119          1754.237
# 1                 177.966   21.493   21.493            42.986
# 2               10169.492  915.254  915.254          1830.508
# 3                  75.451   26.576   26.576            53.151
# 4                   0.000   34.167   34.167            68.333
# ...                   ...      ...      ...               ...
# 51732               0.000    0.000    0.000             0.000
# 51733               0.000    0.000    0.000             0.000
# 51734               0.000    0.000    0.000             0.000
# 51735               0.000    0.000    0.000             0.000
# 51736               0.000    0.000    0.000             0.000
#
#        TOTAL_BILL_VALUE  TOTAL_NOOF_ITEMS_PURCHASED PAYMENT_TYPE  \
# 0               11500.0                           1        Paytm
# 1                 665.0                           6        Paytm
# 2               12000.0                           1        Paytm
# 3                 920.0                           5         Cash
# 4                 860.0                           7         Card
# ...                 ...                         ...          ...
# 51732             205.0                           4         Card
# 51733             880.0                           7       Credit
# 51734             225.0                           1         Card
# 51735             390.0                           3         Cash
# 51736             770.0                           5         Card
#
#       ONLINE/OFFLINE month_year  Hour Dayofweek
# 0             Online    2022-09    21    Friday
# 1             Online    2022-09    21    Friday
# 2             Online    2022-09    20    Friday
# 3            Offline    2022-09    20    Friday
# 4             Online    2022-09    20    Friday
# ...              ...        ...   ...       ...
# 51732         Online    2019-01    13   Tuesday
# 51733         Online    2019-01    13   Tuesday
# 51734         Online    2019-01    13   Tuesday
# 51735        Offline    2019-01    13   Tuesday
# 51736         Online    2019-01    13   Tuesday
#
# [51737 rows x 18 columns]

# %%
plt.figure(figsize=(30,25))
sns.countplot(x='month_year',data=Billwise_sales, palette='rainbow')
plt.title("MONTHLY SALES")
# Out:
# Text(0.5, 1.0, 'MONTHLY SALES')

# %%
Billwise_sales['month_year'].max()
# Out:
# Period('2022-09', 'M')

# %%
Billwise_sales['month_year'].min()
# Out:
# Period('2019-01', 'M')

# %%
Billwise_sales['month_year'].value_counts()
# Out:
# 2019-01    1385
# 2019-07    1355
# 2019-08    1354
# 2021-03    1349
# 2022-03    1341
# 2019-12    1318
# 2021-01    1288
# 2019-09    1283
# 2020-12    1279
# 2020-02    1275
# 2022-08    1270
# 2021-04    1258
# 2019-11    1245
# 2020-03    1241
# 2019-10    1238
# 2021-02    1232
# 2022-01    1229
# 2021-12    1221
# 2020-11    1214
# 2022-07    1206
# 2022-09    1198
# 2021-10    1198
# 2021-07    1178
# 2022-05    1177
# 2020-10    1167
# 2021-09    1164
# 2020-01    1156
# 2022-06    1153
# 2021-08    1137
# 2022-04    1135
# 2019-05    1132
# 2021-06    1126
# 2021-11    1126
# 2022-02    1125
# 2019-06    1123
# 2019-02    1100
# 2020-06    1044
# 2020-07    1030
# 2019-04    1026
# 2020-09    1025
# 2019-03     999
# 2020-08     911
# 2021-05     890
# 2020-05     603
# 2020-04     233
# Freq: M, Name: month_year, dtype: int64

# %%
Billwise_sales['PAYMENT_TYPE'].value_counts()
# Out:
# Cash             21903
# Paytm            15294
# Card             14007
# NEFT               177
# Credit             148
# Google Pay         100
# Redeem Points       71
# Dunzo               19
# Swiggy              18
# Name: PAYMENT_TYPE, dtype: int64

# %%
Billwise_sales['ONLINE/OFFLINE'].value_counts()
# Out:
# Online     29833
# Offline    21171
# Refund       733
# Name: ONLINE/OFFLINE, dtype: int64

# %%
sns.countplot("ONLINE/OFFLINE", data=Billwise_sales)
# Out:
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ONLINE/OFFLINE', ylabel='count'>

# %%
sns.countplot("PAYMENT_TYPE", data=Billwise_sales)
Billwise_sales[['PAYMENT_TYPE','TOTAL_BILL_VALUE']].groupby(['PAYMENT_TYPE']).sum()
# Out:
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
#                TOTAL_BILL_VALUE
# PAYMENT_TYPE
# Card                17592731.00
# Cash                15580472.37
# Credit                313757.00
# Dunzo                  12446.00
# Google Pay            140247.00
# NEFT                  835729.00
# Paytm               17720675.00
# Redeem Points         124439.00
# Swiggy                 15949.00

# %%
Billwise_sales['PAYMENT_TYPE'].value_counts()
# Out:
# Cash             21903
# Paytm            15294
# Card             14007
# NEFT               177
# Credit             148
# Google Pay         100
# Redeem Points       71
# Dunzo               19
# Swiggy              18
# Name: PAYMENT_TYPE, dtype: int64

# %%
Billwise_sales.groupby('Dayofweek')['TOTAL_BILL_VALUE','TOTAL_NOOF_ITEMS_PURCHASED'].sum()
# Out:
# C:\Users\BHARAT~1\AppData\Local\Temp/ipykernel_18472/3204175903.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Billwise_sales.groupby('Dayofweek')['TOTAL_BILL_VALUE','TOTAL_NOOF_ITEMS_PURCHASED'].sum()
#            TOTAL_BILL_VALUE  TOTAL_NOOF_ITEMS_PURCHASED
# Dayofweek
# Friday           6775347.50                       27397
# Monday           7284356.95                       29263
# Saturday         9402053.53                       39852
# Sunday           9443531.20                       40148
# Thursday         6579028.00                       26693
# Tuesday          6302398.53                       27015
# Wednesday        6549729.66                       27705

# %%
Billwise_sales['Dayofweek']= Billwise_sales['DATE'].dt.day_name()
plt.figure(figsize=(8,5))
sns.countplot(x='Dayofweek',data=Billwise_sales, palette='rainbow')
plt.title("DAY OF THE WEEK")
# Out:
# Text(0.5, 1.0, 'DAY OF THE WEEK')

# %%
Billwise_sales['Year'] = pd.DatetimeIndex(Billwise_sales['DATE']).year
plt.figure(figsize=(8,5))
sns.countplot(x='Year',data=Billwise_sales, palette='rainbow')
plt.title("YEARLY SALES")
# Out:
# Text(0.5, 1.0, 'YEARLY SALES')

# %%
plt.figure(figsize=(20,15))
sns.countplot(x='TOTAL_NOOF_ITEMS_PURCHASED',data=Billwise_sales, palette='rainbow')
plt.title("TOTAL NO OF ITEMS PURCHASED")
# Out:
# Text(0.5, 1.0, 'TOTAL NO OF ITEMS PURCHASED')

# %%
Billwise_sales
# Out:
#         TIME       DATE       BILL_NO                  CONSUMER_NAME  \
# 0      21:12 2022-09-30  AA/2223/7106                   Praveen Kphb
# 1      21:11 2022-09-30  AA/2223/7105                   Praveen Kphb
# 2      20:43 2022-09-30  AA/2223/7104                          Guest
# 3      20:15 2022-09-30  AA/2223/7103       Venkata Ratnam 6th Phase
# 4      20:08 2022-09-30  AA/2223/7102  Raghavendra Vivekananda Nagar
# ...      ...        ...           ...                            ...
# 51732  13:55 2019-01-01     A-A000128                         ravi l
# 51733  13:48 2019-01-01     A-A000127                         balaji
# 51734  13:40 2019-01-01     A-A000126                           ramu
# 51735  13:37 2019-01-01     A-A000125                          ratna
# 51736  13:29 2019-01-01     A-A000124              Ramesh Hydernagar
#
#        Taxable_Amount_0%  Taxable_Amount_5%  Taxable_Amount_12%  \
# 0                    0.0              0.000               0.000
# 1                  225.0            219.048               0.000
# 2                    0.0              0.000               0.000
# 3                    0.0            791.398               0.000
# 4                    0.0            380.952             410.714
# ...                  ...                ...                 ...
# 51732              205.0              0.000               0.000
# 51733              880.0              0.000               0.000
# 51734              225.0              0.000               0.000
# 51735              390.0              0.000               0.000
# 51736              770.0              0.000               0.000
#
#        Taxable_Amount_18%     CGST     SGST  TOTAL_TAX_AMOUNT  \
# 0                9745.763  877.119  877.119          1754.237
# 1                 177.966   21.493   21.493            42.986
# 2               10169.492  915.254  915.254          1830.508
# 3                  75.451   26.576   26.576            53.151
# 4                   0.000   34.167   34.167            68.333
# ...                   ...      ...      ...               ...
# 51732               0.000    0.000    0.000             0.000
# 51733               0.000    0.000    0.000             0.000
# 51734               0.000    0.000    0.000             0.000
# 51735               0.000    0.000    0.000             0.000
# 51736               0.000    0.000    0.000             0.000
#
#        TOTAL_BILL_VALUE  TOTAL_NOOF_ITEMS_PURCHASED PAYMENT_TYPE  \
# 0               11500.0                           1        Paytm
# 1                 665.0                           6        Paytm
# 2               12000.0                           1        Paytm
# 3                 920.0                           5         Cash
# 4                 860.0                           7         Card
# ...                 ...                         ...          ...
# 51732             205.0                           4         Card
# 51733             880.0                           7       Credit
# 51734             225.0                           1         Card
# 51735             390.0                           3         Cash
# 51736             770.0                           5         Card
#
#       ONLINE/OFFLINE month_year  Hour Dayofweek  Year
# 0             Online    2022-09    21    Friday  2022
# 1             Online    2022-09    21    Friday  2022
# 2             Online    2022-09    20    Friday  2022
# 3            Offline    2022-09    20    Friday  2022
# 4             Online    2022-09    20    Friday  2022
# ...              ...        ...   ...       ...   ...
# 51732         Online    2019-01    13   Tuesday  2019
# 51733         Online    2019-01    13   Tuesday  2019
# 51734         Online    2019-01    13   Tuesday  2019
# 51735        Offline    2019-01    13   Tuesday  2019
# 51736         Online    2019-01    13   Tuesday  2019
#
# [51737 rows x 19 columns]

# %%
Billwise_sales['DATE'].min()
# Out:
# Timestamp('2019-01-01 00:00:00')

# %%
Billwise_sales['DATE'].max()
# Out:
# Timestamp('2022-09-30 00:00:00')

# %%
Billwise_sales['DATE'].max() - Billwise_sales['DATE'].min()
# Out:
# Timedelta('1368 days 00:00:00')

# %%
filt = (Billwise_sales['DATE'] >= pd.to_datetime('2019-01-01')) & (Billwise_sales['DATE'] < pd.to_datetime('2020-01-01'))
Billwise_sales.loc[filt]
# Out:
#         TIME       DATE       BILL_NO          CONSUMER_NAME  \
# 37179  20:57 2019-12-31  A/1920/10962                Jyoshna
# 37180  20:55 2019-12-31  A/1920/10961                  Kumar
# 37181  20:48 2019-12-31  A/1920/10960              Jagadeesh
# 37182  20:25 2019-12-31  A/1920/10959                  Guest
# 37183  19:59 2019-12-31  A/1920/10958  Vijay Kumar 9th Phase
# ...      ...        ...           ...                    ...
# 51732  13:55 2019-01-01     A-A000128                 ravi l
# 51733  13:48 2019-01-01     A-A000127                 balaji
# 51734  13:40 2019-01-01     A-A000126                   ramu
# 51735  13:37 2019-01-01     A-A000125                  ratna
# 51736  13:29 2019-01-01     A-A000124      Ramesh Hydernagar
#
#        Taxable_Amount_0%  Taxable_Amount_5%  Taxable_Amount_12%  \
# 37179              710.0                0.0                 0.0
# 37180              130.0                0.0                 0.0
# 37181              220.0                0.0                 0.0
# 37182               50.0                0.0                 0.0
# 37183             1420.0                0.0                 0.0
# ...                  ...                ...                 ...
# 51732              205.0                0.0                 0.0
# 51733              880.0                0.0                 0.0
# 51734              225.0                0.0                 0.0
# 51735              390.0                0.0                 0.0
# 51736              770.0                0.0                 0.0
#
#        Taxable_Amount_18%  CGST  SGST  TOTAL_TAX_AMOUNT  TOTAL_BILL_VALUE  \
# 37179                 0.0   0.0   0.0               0.0             710.0
# 37180                 0.0   0.0   0.0               0.0             130.0
# 37181                 0.0   0.0   0.0               0.0             220.0
# 37182                 0.0   0.0   0.0               0.0              50.0
# 37183                 0.0   0.0   0.0               0.0            1420.0
# ...                   ...   ...   ...               ...               ...
# 51732                 0.0   0.0   0.0               0.0             205.0
# 51733                 0.0   0.0   0.0               0.0             880.0
# 51734                 0.0   0.0   0.0               0.0             225.0
# 51735                 0.0   0.0   0.0               0.0             390.0
# 51736                 0.0   0.0   0.0               0.0             770.0
#
#        TOTAL_NOOF_ITEMS_PURCHASED PAYMENT_TYPE ONLINE/OFFLINE month_year  \
# 37179                           2         Card         Online    2019-12
# 37180                           3         Cash        Offline    2019-12
# 37181                           1         Card         Online    2019-12
# 37182                           1         Cash        Offline    2019-12
# 37183                          13         Cash        Offline    2019-12
# ...                           ...          ...            ...        ...
# 51732                           4         Card         Online    2019-01
# 51733                           7       Credit         Online    2019-01
# 51734                           1         Card         Online    2019-01
# 51735                           3         Cash        Offline    2019-01
# 51736                           5         Card         Online    2019-01
#
#        Hour Dayofweek  Year
# 37179    20   Tuesday  2019
# 37180    20   Tuesday  2019
# 37181    20   Tuesday  2019
# 37182    20   Tuesday  2019
# 37183    19   Tuesday  2019
# ...     ...       ...   ...
# 51732    13   Tuesday  2019
# 51733    13   Tuesday  2019
# 51734    13   Tuesday  2019
# 51735    13   Tuesday  2019
# 51736    13   Tuesday  2019
#
# [14558 rows x 19 columns]

# %%
filt = (Billwise_sales['DATE'] >= pd.to_datetime('2020-01-01')) & (Billwise_sales['DATE'] < pd.to_datetime('2021-01-01'))
Billwise_sales.loc[filt]
# Out:
#         TIME       DATE       BILL_NO               CONSUMER_NAME  \
# 25001  19:44 2020-12-31   A/2021/8410                       Guest
# 25002  19:31 2020-12-31   A/2021/8409            haribabu ponduri
# 25003  19:17 2020-12-31   A/2021/8407                       Tagor
# 25004  18:44 2020-12-31   A/2021/8404                      Santhu
# 25005  18:40 2020-12-31   A/2021/8403  Vijaysri SMR Vinay Founten
# ...      ...        ...           ...                         ...
# 37174  12:37 2020-01-01  A/1920/10967       Ramana Reddy Kondapur
# 37175  11:59 2020-01-01  A/1920/10966                     Sujatha
# 37176  11:48 2020-01-01  A/1920/10965                    Niharika
# 37177  11:05 2020-01-01  A/1920/10964                      Ramana
# 37178  10:28 2020-01-01  A/1920/10963                 Subramanyam
#
#        Taxable_Amount_0%  Taxable_Amount_5%  Taxable_Amount_12%  \
# 25001                0.0              0.000             258.929
# 25002                0.0           1357.143              89.286
# 25003                0.0           1714.286               0.000
# 25004                0.0            380.952               0.000
# 25005                0.0           1600.000               0.000
# ...                  ...                ...                 ...
# 37174             2625.0              0.000               0.000
# 37175              645.0              0.000               0.000
# 37176              100.0              0.000               0.000
# 37177              545.0              0.000               0.000
# 37178              250.0              0.000               0.000
#
#        Taxable_Amount_18%    CGST    SGST  TOTAL_TAX_AMOUNT  TOTAL_BILL_VALUE  \
# 25001               0.000  15.536  15.536            31.071             290.0
# 25002               0.000  39.286  39.286            78.571            1525.0
# 25003               0.000  42.857  42.857            85.714            1800.0
# 25004              42.373  13.338  13.338            26.675             450.0
# 25005               0.000  40.000  40.000            80.000            1680.0
# ...                   ...     ...     ...               ...               ...
# 37174               0.000   0.000   0.000             0.000            2625.0
# 37175               0.000   0.000   0.000             0.000             645.0
# 37176               0.000   0.000   0.000             0.000             100.0
# 37177               0.000   0.000   0.000             0.000             545.0
# 37178               0.000   0.000   0.000             0.000             250.0
#
#        TOTAL_NOOF_ITEMS_PURCHASED PAYMENT_TYPE ONLINE/OFFLINE month_year  \
# 25001                           1         Cash        Offline    2020-12
# 25002                           7        Paytm         Online    2020-12
# 25003                           1         Cash        Offline    2020-12
# 25004                           4        Paytm         Online    2020-12
# 25005                           5         Cash        Offline    2020-12
# ...                           ...          ...            ...        ...
# 37174                          11         Cash        Offline    2020-01
# 37175                           6         Card         Online    2020-01
# 37176                           1         Cash        Offline    2020-01
# 37177                           2         Cash        Offline    2020-01
# 37178                           1         Cash        Offline    2020-01
#
#        Hour  Dayofweek  Year
# 25001    19   Thursday  2020
# 25002    19   Thursday  2020
# 25003    19   Thursday  2020
# 25004    18   Thursday  2020
# 25005    18   Thursday  2020
# ...     ...        ...   ...
# 37174    12  Wednesday  2020
# 37175    11  Wednesday  2020
# 37176    11  Wednesday  2020
# 37177    11  Wednesday  2020
# 37178    10  Wednesday  2020
#
# [12178 rows x 19 columns]

# %%
filt = (Billwise_sales['DATE'] >= pd.to_datetime('2021-01-01')) & (Billwise_sales['DATE'] < pd.to_datetime('2022-01-01'))
Billwise_sales.loc[filt]
# Out:
#         TIME       DATE       BILL_NO            CONSUMER_NAME  \
# 10834  19:58 2021-12-31  AA/2122/3122                   Prasad
# 10835  19:55 2021-12-31  AA/2122/3121              Bhaskar Rao
# 10836  19:43 2021-12-31  AA/2122/3120  Tulasi Manjeera Trinity
# 10837  19:24 2021-12-31  AA/2122/3119                    Guest
# 10838  18:44 2021-12-31  AA/2122/3118  Vamshidar Bharath Nagar
# ...      ...        ...           ...                      ...
# 24996  12:24 2021-01-01   A/2021/8415             Shareef Kphb
# 24997  11:28 2021-01-01   A/2021/8414              venkat KPHB
# 24998  11:26 2021-01-01   A/2021/8413     Siva Kumar Kukatpali
# 24999  11:08 2021-01-01   A/2021/8412               Raju Reddy
# 25000  10:45 2021-01-01   A/2021/8411   Ravendra Babu Nizampet
#
#        Taxable_Amount_0%  Taxable_Amount_5%  Taxable_Amount_12%  \
# 10834              0.000            152.381                 0.0
# 10835              0.000           6857.143                 0.0
# 10836              0.000            457.143                 0.0
# 10837              0.000             19.048                 0.0
# 10838              0.000            323.810                 0.0
# ...                  ...                ...                 ...
# 24996            265.977            175.515                 0.0
# 24997              0.000            133.333                 0.0
# 24998            110.000           1047.619                 0.0
# 24999            348.000            785.714                 0.0
# 25000             63.000            371.429                 0.0
#
#        Taxable_Amount_18%     CGST     SGST  TOTAL_TAX_AMOUNT  \
# 10834               0.000    3.810    3.810             7.619
# 10835               0.000  171.429  171.429           342.857
# 10836               0.000   11.429   11.429            22.857
# 10837               0.000    0.476    0.476             0.952
# 10838              67.797   14.197   14.197            28.394
# ...                   ...      ...      ...               ...
# 24996              59.095    9.707    9.707            19.413
# 24997               0.000    3.333    3.333             6.667
# 24998               0.000   26.190   26.190            52.381
# 24999             330.508   49.389   49.389            98.777
# 25000               0.000    9.286    9.286            18.571
#
#        TOTAL_BILL_VALUE  TOTAL_NOOF_ITEMS_PURCHASED PAYMENT_TYPE  \
# 10834             160.0                           1         Card
# 10835            7200.0                           3         Card
# 10836             480.0                           1        Paytm
# 10837              20.0                           1         Cash
# 10838             420.0                           8        Paytm
# ...                 ...                         ...          ...
# 24996             520.0                           6         Cash
# 24997             140.0                           1        Paytm
# 24998            1210.0                           5        Paytm
# 24999            1563.0                          15        Paytm
# 25000             453.0                           2        Paytm
#
#       ONLINE/OFFLINE month_year  Hour Dayofweek  Year
# 10834         Online    2021-12    19    Friday  2021
# 10835         Online    2021-12    19    Friday  2021
# 10836         Online    2021-12    19    Friday  2021
# 10837        Offline    2021-12    19    Friday  2021
# 10838         Online    2021-12    18    Friday  2021
# ...              ...        ...   ...       ...   ...
# 24996        Offline    2021-01    12    Friday  2021
# 24997         Online    2021-01    11    Friday  2021
# 24998         Online    2021-01    11    Friday  2021
# 24999         Online    2021-01    11    Friday  2021
# 25000         Online    2021-01    10    Friday  2021
#
# [14167 rows x 19 columns]

# %%
filt = (Billwise_sales['DATE'] >= pd.to_datetime('2022-01-01')) & (Billwise_sales['DATE'] <= pd.to_datetime('2022-09-30'))
Billwise_sales.loc[filt]
# Out:
#         TIME       DATE       BILL_NO                  CONSUMER_NAME  \
# 0      21:12 2022-09-30  AA/2223/7106                   Praveen Kphb
# 1      21:11 2022-09-30  AA/2223/7105                   Praveen Kphb
# 2      20:43 2022-09-30  AA/2223/7104                          Guest
# 3      20:15 2022-09-30  AA/2223/7103       Venkata Ratnam 6th Phase
# 4      20:08 2022-09-30  AA/2223/7102  Raghavendra Vivekananda Nagar
# ...      ...        ...           ...                            ...
# 10829  12:28 2022-01-01  AA/2122/3127               Sathyam Shaikpet
# 10830  12:23 2022-01-01  AA/2122/3126         Suresh Jagadgiri Gutta
# 10831  12:18 2022-01-01  AA/2122/3125             Chandrashekar Kphb
# 10832  11:21 2022-01-01  AA/2122/3124                          Guest
# 10833  09:42 2022-01-01  AA/2122/3123       Phanendra KPHB 3rd Phase
#
#        Taxable_Amount_0%  Taxable_Amount_5%  Taxable_Amount_12%  \
# 0                    0.0              0.000               0.000
# 1                  225.0            219.048               0.000
# 2                    0.0              0.000               0.000
# 3                    0.0            791.398               0.000
# 4                    0.0            380.952             410.714
# ...                  ...                ...                 ...
# 10829               60.0           1971.429             500.000
# 10830              150.0            935.238            1250.000
# 10831                0.0            809.524               0.000
# 10832                0.0            133.333               0.000
# 10833              130.0            228.571               0.000
#
#        Taxable_Amount_18%     CGST     SGST  TOTAL_TAX_AMOUNT  \
# 0                9745.763  877.119  877.119          1754.237
# 1                 177.966   21.493   21.493            42.986
# 2               10169.492  915.254  915.254          1830.508
# 3                  75.451   26.576   26.576            53.151
# 4                   0.000   34.167   34.167            68.333
# ...                   ...      ...      ...               ...
# 10829             368.644  112.464  112.464           224.927
# 10830             169.492  113.635  113.635           227.270
# 10831               0.000   20.238   20.238            40.476
# 10832               0.000    3.333    3.333             6.667
# 10833               0.000    5.714    5.714            11.429
#
#        TOTAL_BILL_VALUE  TOTAL_NOOF_ITEMS_PURCHASED PAYMENT_TYPE  \
# 0               11500.0                           1        Paytm
# 1                 665.0                           6        Paytm
# 2               12000.0                           1        Paytm
# 3                 920.0                           5         Cash
# 4                 860.0                           7         Card
# ...                 ...                         ...          ...
# 10829            3125.0                          16         Card
# 10830            2732.0                           8        Paytm
# 10831             850.0                           7         Card
# 10832             140.0                           2        Paytm
# 10833             370.0                           2        Paytm
#
#       ONLINE/OFFLINE month_year  Hour Dayofweek  Year
# 0             Online    2022-09    21    Friday  2022
# 1             Online    2022-09    21    Friday  2022
# 2             Online    2022-09    20    Friday  2022
# 3            Offline    2022-09    20    Friday  2022
# 4             Online    2022-09    20    Friday  2022
# ...              ...        ...   ...       ...   ...
# 10829         Online    2022-01    12  Saturday  2022
# 10830         Online    2022-01    12  Saturday  2022
# 10831         Online    2022-01    12  Saturday  2022
# 10832         Online    2022-01    11  Saturday  2022
# 10833         Online    2022-01     9  Saturday  2022
#
# [10834 rows x 19 columns]

# %%
sorteddf = Billwise_sales.groupby(['DATE','Hour'])['TOTAL_BILL_VALUE','TOTAL_NOOF_ITEMS_PURCHASED'].sum()
sorteddf
# Out:
# C:\Users\BHARAT~1\AppData\Local\Temp/ipykernel_18472/1691503584.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sorteddf = Billwise_sales.groupby(['DATE','Hour'])['TOTAL_BILL_VALUE','TOTAL_NOOF_ITEMS_PURCHASED'].sum()
#                  TOTAL_BILL_VALUE  TOTAL_NOOF_ITEMS_PURCHASED
# DATE       Hour
# 2019-01-01 13              3295.0                          27
#            14              6585.0                          51
#            15              1185.0                          10
#            16              5065.0                          40
#            17              3080.0                          29
# ...                           ...                         ...
# 2022-09-30 17              3500.0                          15
#            18             14710.0                           4
#            19               340.0                           3
#            20             13780.0                          13
#            21             12165.0                           7
#
# [14077 rows x 2 columns]

# %%
sorteddf['TOTAL_BILL_VALUE'].plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='DATE,Hour'>

# %%
sorted_df2 = Billwise_sales.groupby('DATE')['TOTAL_BILL_VALUE','TOTAL_NOOF_ITEMS_PURCHASED'].sum().reset_index()
sorted_df2
# Out:
# C:\Users\BHARAT~1\AppData\Local\Temp/ipykernel_18472/473875180.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sorted_df2 = Billwise_sales.groupby('DATE')['TOTAL_BILL_VALUE','TOTAL_NOOF_ITEMS_PURCHASED'].sum().reset_index()
#            DATE  TOTAL_BILL_VALUE  TOTAL_NOOF_ITEMS_PURCHASED
# 0    2019-01-01           37420.0                         296
# 1    2019-01-02           36140.0                         245
# 2    2019-01-03           33921.0                         163
# 3    2019-01-04           45510.0                         348
# 4    2019-01-05           31980.0                         224
# ...         ...               ...                         ...
# 1356 2022-09-26           26845.0                         108
# 1357 2022-09-27           29009.0                         119
# 1358 2022-09-28           56172.0                         168
# 1359 2022-09-29           36421.0                         105
# 1360 2022-09-30           89272.0                         163
#
# [1361 rows x 3 columns]

# %%
Billwise_sales.groupby('month_year')['TOTAL_BILL_VALUE','TOTAL_NOOF_ITEMS_PURCHASED'].sum()
# Out:
# C:\Users\BHARAT~1\AppData\Local\Temp/ipykernel_18472/1402473909.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   Billwise_sales.groupby('month_year')['TOTAL_BILL_VALUE','TOTAL_NOOF_ITEMS_PURCHASED'].sum()
#             TOTAL_BILL_VALUE  TOTAL_NOOF_ITEMS_PURCHASED
# month_year
# 2019-01            855053.00                        5657
# 2019-02            667027.00                        4349
# 2019-03            699745.00                        4249
# 2019-04            788361.00                        4567
# 2019-05            803643.00                        5018
# 2019-06           1092992.00                        4829
# 2019-07           1029301.00                        6173
# 2019-08           1082340.00                        5683
# 2019-09           1554605.00                        5144
# 2019-10           1087014.00                        5070
# 2019-11            971971.00                        4820
# 2019-12           1084130.00                        5236
# 2020-01           1026015.00                        4379
# 2020-02           1160771.00                        5008
# 2020-03           1354048.00                        5325
# 2020-04            169301.00                         708
# 2020-05            648946.00                        2084
# 2020-06           1117881.00                        3890
# 2020-07           1206249.00                        4396
# 2020-08           1154275.00                        4027
# 2020-09           1204686.00                        4493
# 2020-10           1164519.00                        4820
# 2020-11           1155826.00                        5146
# 2020-12           1363599.00                        5340
# 2021-01           1468907.00                        5778
# 2021-02           1432575.00                        5636
# 2021-03           1501119.00                        5650
# 2021-04           1524932.00                        5675
# 2021-05           1192114.00                        4068
# 2021-06           1308917.00                        5120
# 2021-07           1366617.00                        5260
# 2021-08           1110115.00                        4860
# 2021-09           1181161.00                        4950
# 2021-10           1343208.00                        5241
# 2021-11           1251024.00                        5091
# 2021-12           1281583.95                        5144
# 2022-01           1300000.16                        5290
# 2022-02           1205652.97                        4781
# 2022-03           1602380.00                        5692
# 2022-04           1121359.00                        4782
# 2022-05           1300272.30                        4695
# 2022-06           1302230.53                        4850
# 2022-07           1343502.00                        5109
# 2022-08           1352086.00                        5268
# 2022-09           1404391.46                        4722

# %%
Billwise_sales = Billwise_sales[['month_year','TOTAL_BILL_VALUE','TOTAL_NOOF_ITEMS_PURCHASED']].groupby('month_year').sum()
Billwise_sales.reset_index(inplace = True)
Billwise_sales
# Out:
#    month_year  TOTAL_BILL_VALUE  TOTAL_NOOF_ITEMS_PURCHASED
# 0     2019-01         855053.00                        5657
# 1     2019-02         667027.00                        4349
# 2     2019-03         699745.00                        4249
# 3     2019-04         788361.00                        4567
# 4     2019-05         803643.00                        5018
# 5     2019-06        1092992.00                        4829
# 6     2019-07        1029301.00                        6173
# 7     2019-08        1082340.00                        5683
# 8     2019-09        1554605.00                        5144
# 9     2019-10        1087014.00                        5070
# 10    2019-11         971971.00                        4820
# 11    2019-12        1084130.00                        5236
# 12    2020-01        1026015.00                        4379
# 13    2020-02        1160771.00                        5008
# 14    2020-03        1354048.00                        5325
# 15    2020-04         169301.00                         708
# 16    2020-05         648946.00                        2084
# 17    2020-06        1117881.00                        3890
# 18    2020-07        1206249.00                        4396
# 19    2020-08        1154275.00                        4027
# 20    2020-09        1204686.00                        4493
# 21    2020-10        1164519.00                        4820
# 22    2020-11        1155826.00                        5146
# 23    2020-12        1363599.00                        5340
# 24    2021-01        1468907.00                        5778
# 25    2021-02        1432575.00                        5636
# 26    2021-03        1501119.00                        5650
# 27    2021-04        1524932.00                        5675
# 28    2021-05        1192114.00                        4068
# 29    2021-06        1308917.00                        5120
# 30    2021-07        1366617.00                        5260
# 31    2021-08        1110115.00                        4860
# 32    2021-09        1181161.00                        4950
# 33    2021-10        1343208.00                        5241
# 34    2021-11        1251024.00                        5091
# 35    2021-12        1281583.95                        5144
# 36    2022-01        1300000.16                        5290
# 37    2022-02        1205652.97                        4781
# 38    2022-03        1602380.00                        5692
# 39    2022-04        1121359.00                        4782
# 40    2022-05        1300272.30                        4695
# 41    2022-06        1302230.53                        4850
# 42    2022-07        1343502.00                        5109
# 43    2022-08        1352086.00                        5268
# 44    2022-09        1404391.46                        4722

# %%
Billwise_sales.plot.line(x = 'month_year', y = 'TOTAL_BILL_VALUE', 
                             color = 'salmon', title = 'Monthly Sales')
# Out:
# <AxesSubplot:title={'center':'Monthly Sales'}, xlabel='month_year'>

# %%
ts_df = sorted_df2.set_index('DATE')
ts_df.index
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10',
#                ...
#                '2022-09-21', '2022-09-22', '2022-09-23', '2022-09-24',
#                '2022-09-25', '2022-09-26', '2022-09-27', '2022-09-28',
#                '2022-09-29', '2022-09-30'],
#               dtype='datetime64[ns]', name='DATE', length=1361, freq=None)

# %%
sns.set()
plt.ylabel('Total Sale')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.plot(ts_df.index, ts_df['TOTAL_BILL_VALUE'],)

# %%
train = ts_df[ts_df.index < pd.to_datetime("2022-01-01", format='%Y-%m-%d')]
test = ts_df[ts_df.index > pd.to_datetime("2022-01-01", format='%Y-%m-%d')]

plt.plot(train, color = "black")
plt.plot(test, color = "red")
plt.ylabel('SALE')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.title("Train/Test split for PVS Data")
plt.show()

# %%
tsdf2 = sorted_df2.groupby('DATE')['TOTAL_BILL_VALUE'].sum().reset_index()
tsdf2
tsdf1 = sorted_df2.groupby('DATE')['TOTAL_NOOF_ITEMS_PURCHASED'].sum().reset_index()
tsdf1
# Out:
#            DATE  TOTAL_NOOF_ITEMS_PURCHASED
# 0    2019-01-01                         296
# 1    2019-01-02                         245
# 2    2019-01-03                         163
# 3    2019-01-04                         348
# 4    2019-01-05                         224
# ...         ...                         ...
# 1356 2022-09-26                         108
# 1357 2022-09-27                         119
# 1358 2022-09-28                         168
# 1359 2022-09-29                         105
# 1360 2022-09-30                         163
#
# [1361 rows x 2 columns]

# %%
tsdf1 = tsdf1.set_index('DATE')
tsdf1.index
tsdf2 = tsdf2.set_index('DATE')
tsdf2.index
# Out:
# DatetimeIndex(['2019-01-01', '2019-01-02', '2019-01-03', '2019-01-04',
#                '2019-01-05', '2019-01-06', '2019-01-07', '2019-01-08',
#                '2019-01-09', '2019-01-10',
#                ...
#                '2022-09-21', '2022-09-22', '2022-09-23', '2022-09-24',
#                '2022-09-25', '2022-09-26', '2022-09-27', '2022-09-28',
#                '2022-09-29', '2022-09-30'],
#               dtype='datetime64[ns]', name='DATE', length=1361, freq=None)

# %%
y1 = tsdf1['TOTAL_NOOF_ITEMS_PURCHASED'].resample('MS').mean()
y2 = tsdf2['TOTAL_BILL_VALUE'].resample('MS').mean()

# %%
y1.plot(figsize=(15, 6))
plt.show()
y2.plot(figsize=(15, 6))
plt.show()

# %%
from pylab import rcParams
import statsmodels.api as sm
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(y1, model='additive')
fig = decomposition.plot()
plt.show()

# %%
decomposition2 = sm.tsa.seasonal_decompose(y2, model='additive')
fig = decomposition2.plot()
plt.show()

# %%
#Determining rolling statistics
rolmean = y2.rolling(window=7).mean()
rolstd = y2.rolling(window=7).std()
print(rolmean,rolstd)
#plot rolling statistics
orig = plt.plot(y2,color='blue',label='Original')
mean = plt.plot(rolmean,color='red',label='Rolling Mean')
std = plt.plot(rolstd,color='black',label = 'Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
plt.show(block=False)
#Mean and standard deviation is stationary
# Out:
# DATE
# 2019-01-01             NaN
# 2019-02-01             NaN
# 2019-03-01             NaN
# 2019-04-01             NaN
# 2019-05-01             NaN
# 2019-06-01             NaN
# 2019-07-01    28103.188799
# 2019-08-01    29150.594329
# 2019-09-01    33150.276302
# 2019-10-01    34934.926071
# 2019-11-01    35679.807680
# 2019-12-01    36972.374501
# 2020-01-01    36821.911775
# 2020-02-01    37796.672938
# 2020-03-01    39717.339166
# 2020-04-01    33178.238826
# 2020-05-01    31159.492282
# 2020-06-01    31854.301806
# 2020-07-01    32417.062175
# 2020-08-01    32682.040722
# 2020-09-01    32700.556978
# 2020-10-01    31158.595820
# 2020-11-01    35798.748541
# 2020-12-01    39092.080338
# 2021-01-01    40537.994163
# 2021-02-01    42288.299133
# 2021-03-01    43886.658580
# 2021-04-01    45411.639533
# 2021-05-01    45538.805431
# 2021-06-01    46267.810193
# 2021-07-01    46281.718027
# 2021-08-01    44628.298672
# 2021-09-01    42943.818740
# 2021-10-01    42216.118280
# 2021-11-01    40911.794470
# 2021-12-01    41324.098387
# 2022-01-01    41081.944439
# 2022-02-01    40935.460909
# 2022-03-01    43203.963213
# 2022-04-01    42919.191785
# 2022-05-01    42721.331416
# 2022-06-01    42965.172035
# 2022-07-01    43250.508671
# 2022-08-01    43490.535583
# 2022-09-01    44026.823301
# Freq: MS, Name: TOTAL_BILL_VALUE, dtype: float64 DATE
# 2019-01-01             NaN
# 2019-02-01             NaN
# 2019-03-01             NaN
# 2019-04-01             NaN
# 2019-05-01             NaN
# 2019-06-01             NaN
# 2019-07-01     5002.929021
# 2019-08-01     5606.765289
# 2019-09-01     9679.467013
# 2019-10-01     8481.672909
# 2019-11-01     7896.370175
# 2019-12-01     6680.138957
# 2020-01-01     6706.121811
# 2020-02-01     6587.318457
# 2020-03-01     7503.165145
# 2020-04-01    13074.883505
# 2020-05-01    13805.530696
# 2020-06-01    13999.341814
# 2020-07-01    14222.948151
# 2020-08-01    14304.390159
# 2020-09-01    14315.561321
# 2020-10-01    12854.635761
# 2020-11-01     6638.460316
# 2020-12-01     2400.444024
# 2021-01-01     3771.582906
# 2021-02-01     5387.591923
# 2021-03-01     5297.349132
# 2021-04-01     5573.762360
# 2021-05-01     5371.387627
# 2021-06-01     4543.752733
# 2021-07-01     4535.750105
# 2021-08-01     5954.548216
# 2021-09-01     5443.626665
# 2021-10-01     4902.663084
# 2021-11-01     3118.654222
# 2021-12-01     2924.500721
# 2022-01-01     2767.663264
# 2022-02-01     2604.598106
# 2022-03-01     3959.489559
# 2022-04-01     4334.906067
# 2022-05-01     4344.665669
# 2022-06-01     4325.700461
# 2022-07-01     4266.208083
# 2022-08-01     4226.976256
# 2022-09-01     4397.795624
# Freq: MS, Name: TOTAL_BILL_VALUE, dtype: float64

# %%
sorted_df2.drop('TOTAL_NOOF_ITEMS_PURCHASED',axis=1,inplace=True)

# %%
sorted_df2.set_index('DATE',inplace=True)
sorted_df2
# Out:
#             TOTAL_BILL_VALUE
# DATE
# 2019-01-01           37420.0
# 2019-01-02           36140.0
# 2019-01-03           33921.0
# 2019-01-04           45510.0
# 2019-01-05           31980.0
# ...                      ...
# 2022-09-26           26845.0
# 2022-09-27           29009.0
# 2022-09-28           56172.0
# 2022-09-29           36421.0
# 2022-09-30           89272.0
#
# [1361 rows x 1 columns]

# %%
#Determining rolling statistics
rolmean = sorted_df2.rolling(window=365).mean()
rolstd = sorted_df2.rolling(window=365).std()
print(rolmean,rolstd)
#plot rolling statistics
orig = plt.plot(sorted_df2,color='blue',label='Original')
mean = plt.plot(rolmean,color='red',label='Rolling Mean')
std = plt.plot(rolstd,color='black',label = 'Rolling Std')
plt.legend(loc='best')
plt.title('Rolling Mean & Standard Deviation')
plt.show(block=False)
#Mean and standard deviation is stationary
# Out:
#             TOTAL_BILL_VALUE
# DATE
# 2019-01-01               NaN
# 2019-01-02               NaN
# 2019-01-03               NaN
# 2019-01-04               NaN
# 2019-01-05               NaN
# ...                      ...
# 2022-09-26      43113.973616
# 2022-09-27      43133.532521
# 2022-09-28      43173.568137
# 2022-09-29      43149.321562
# 2022-09-30      43308.740740
#
# [1361 rows x 1 columns]             TOTAL_BILL_VALUE
# DATE
# 2019-01-01               NaN
# 2019-01-02               NaN
# 2019-01-03               NaN
# 2019-01-04               NaN
# 2019-01-05               NaN
# ...                      ...
# 2022-09-26      18477.374750
# 2022-09-27      18458.594421
# 2022-09-28      18471.013165
# 2022-09-29      18474.060707
# 2022-09-30      18620.143568
#
# [1361 rows x 1 columns]

# %%
#Testing seasonality and stationarity (dicky fuller test)
from statsmodels.tsa.stattools import adfuller

print('Results of Dickey-Fuller Test:')
dftest = adfuller(sorted_df2['TOTAL_BILL_VALUE'],autolag='AIC')
dfoutput = pd.Series(dftest[0:4],index=['Test Statistics','p-value','#lags Used','Number of Observations Used'])
for key,value in dftest[4].items():
    dfoutput['Critical Value (%s)'%key] = value
print(dfoutput)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistics               -5.720473e+00
# p-value                        6.960301e-07
# #lags Used                     1.300000e+01
# Number of Observations Used    1.347000e+03
# Critical Value (1%)           -3.435214e+00
# Critical Value (5%)           -2.863688e+00
# Critical Value (10%)          -2.567914e+00
# dtype: float64

# %%
# Function to test the stationarity
def test_stationarity(df2):
    
    # Determing rolling statistics
    roll_mean = df2.rolling(window=365).mean()
    roll_std = df2.rolling(window=365).std()
# Plotting rolling statistics:
    orig = plt.plot(df2.resample('W').mean(), color='blue',label='Original')
    mean = plt.plot(roll_mean, color='red', label='Rolling Mean')
    std = plt.plot(roll_std, color='green', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.show(block=False)
    
  # Performing Dickey-Fuller test:
    print('Results of Dickey-Fuller Test:')
    result = adfuller(df2, autolag='AIC')
    print('ADF Statistic: %f' % result[0])
    print('p-value: %f' % result[1])
    print('Critical Values:')
    for key, value in result[4].items():
           print(key, value)
# Testing stationarity of store type a
test_stationarity(sorted_df2)
# Out:
# Results of Dickey-Fuller Test:
# ADF Statistic: -5.720473
# p-value: 0.000001
# Critical Values:
# 1% -3.4352139981780865
# 5% -2.863688081179776
# 10% -2.567913641703717

# %%
## Regression Models

# %%
sorted_df2['Previous_day_sale']=sorted_df2['TOTAL_BILL_VALUE'].shift(+1)
sorted_df2['Two_days_before_sale']=sorted_df2['TOTAL_BILL_VALUE'].shift(+2)
sorted_df2['Three_days_before_sale']=sorted_df2['TOTAL_BILL_VALUE'].shift(+3)

# %%
sorted_df2=sorted_df2.dropna()
sorted_df2
# Out:
#             TOTAL_BILL_VALUE  Previous_day_sale  Two_days_before_sale  \
# DATE
# 2019-01-04           45510.0            33921.0               36140.0
# 2019-01-05           31980.0            45510.0               33921.0
# 2019-01-06           57938.0            31980.0               45510.0
# 2019-01-07           29883.0            57938.0               31980.0
# 2019-01-08           19970.0            29883.0               57938.0
# ...                      ...                ...                   ...
# 2022-09-26           26845.0            86078.0               38915.0
# 2022-09-27           29009.0            26845.0               86078.0
# 2022-09-28           56172.0            29009.0               26845.0
# 2022-09-29           36421.0            56172.0               29009.0
# 2022-09-30           89272.0            36421.0               56172.0
#
#             Three_days_before_sale
# DATE
# 2019-01-04                 37420.0
# 2019-01-05                 36140.0
# 2019-01-06                 33921.0
# 2019-01-07                 45510.0
# 2019-01-08                 31980.0
# ...                            ...
# 2022-09-26                 30231.0
# 2022-09-27                 38915.0
# 2022-09-28                 86078.0
# 2022-09-29                 26845.0
# 2022-09-30                 29009.0
#
# [1358 rows x 4 columns]

# %%
import numpy as np
x1,x2,x3,y=sorted_df2['Previous_day_sale'],sorted_df2['Two_days_before_sale'],sorted_df2['Three_days_before_sale'],sorted_df2['TOTAL_BILL_VALUE']
x1,x2,x3,y=np.array(x1),np.array(x2),np.array(x3),np.array(y)
x1,x2,x3,y=x1.reshape(-1,1),x2.reshape(-1,1),x3.reshape(-1,1),y.reshape(-1,1)
final_x=np.concatenate((x1,x2,x3),axis=1)
print(final_x)
# Out:
# [[33921. 36140. 37420.]
#  [45510. 33921. 36140.]
#  [31980. 45510. 33921.]
#  ...
#  [29009. 26845. 86078.]
#  [56172. 29009. 26845.]
#  [36421. 56172. 29009.]]

# %%
X_train,X_test,y_train,y_test=final_x[:-30],final_x[-30:],y[:-30],y[-30:]

# %%
# import the Linear regressor
from sklearn.linear_model import LinearRegression
lin_model=LinearRegression()
lin_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
lin_pred=lin_model.predict(X_test)
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (11,6)
plt.plot(lin_pred,label='Linear_Regression_Predictions')
plt.plot(y_test,label='Actual Sales')
plt.legend(loc="upper left")
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse_lr=sqrt(mean_squared_error(lin_pred,y_test))

# %%
from sklearn.metrics import mean_absolute_error as mae
mae_lr = mae(y_test,lin_pred)

# %%
print('Mean Squared Error for Linear Regression Model is:',rmse_lr)
print('Mean Absolute Error for Linear Regression Model is:',mae_lr)
# Out:
# Mean Squared Error for Linear Regression Model is: 20922.4629299157
# Mean Absolute Error for Linear Regression Model is: 16444.800471961942

# %%
# import the Random Forest regressor
from sklearn.ensemble import RandomForestRegressor
rf_model=RandomForestRegressor(n_estimators=100,max_features=3, random_state=1)
rf_model.fit(X_train,y_train)
# Out:
# C:\Users\BHARAT~1\AppData\Local\Temp/ipykernel_18472/1086805759.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   rf_model.fit(X_train,y_train)
# RandomForestRegressor(max_features=3, random_state=1)

# %%
pred=rf_model.predict(X_test)
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (12,8)
plt.plot(pred,label='Random_Forest_Predictions')
plt.plot(y_test,label='Actual Sales')
plt.legend(loc="upper left")
plt.show()

# %%
rmse_rf=sqrt(mean_squared_error(pred,y_test))
print('Mean Squared Error for Random Forest Model is:',rmse_rf)
# Out:
# Mean Squared Error for Random Forest Model is: 22101.703245631434

# %%
from sklearn.metrics import mean_absolute_error as mae
mae_rf = mae(y_test,pred)
print('Mean Absolute Error for Random Forest Regression Model is:',mae_rf)
# Out:
# Mean Absolute Error for Random Forest Regression Model is: 17388.626300000004

# %%
# import the Decission tree regressor
from sklearn.tree import DecisionTreeRegressor 
regressor = DecisionTreeRegressor(random_state = 0) 
regressor.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
ydt_pred = regressor.predict(X_test)
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (12,8)
plt.plot(ydt_pred,label='Decision_Tree_Regression_Predictions')
plt.plot(y_test,label='Actual Sales')
plt.legend(loc="upper left")
plt.show()

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse_dt=sqrt(mean_squared_error(ydt_pred,y_test))
print('Mean Squared Error for Decission Tree Model is:',rmse_dt)
# Out:
# Mean Squared Error for Decission Tree Model is: 27666.577699606918

# %%
from sklearn.metrics import mean_absolute_error as mae
mae_dt = mae(y_test,ydt_pred)
print('Mean Absolute Error for Decission Tree Regression Model is:',mae_dt)
# Out:
# Mean Absolute Error for Decission Tree Regression Model is: 21729.38466666667

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\bharathi kondaveeti\anaconda3\lib\site-packages (1.7.1)
# Requirement already satisfied: scipy in c:\users\bharathi kondaveeti\anaconda3\lib\site-packages (from xgboost) (1.7.1)
# Requirement already satisfied: numpy in c:\users\bharathi kondaveeti\anaconda3\lib\site-packages (from xgboost) (1.22.4)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\bharathi kondaveeti\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\bharathi kondaveeti\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\bharathi kondaveeti\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\bharathi kondaveeti\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\bharathi kondaveeti\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\bharathi kondaveeti\anaconda3\lib\site-packages)

# %%
import xgboost as xgb
xgb_r = xgb.XGBRegressor(objective ='reg:linear',
                  n_estimators = 10, seed = 123)

# %%
xgb_r.fit(X_train,y_train)
yxgb_pred = xgb_r.predict(X_test)
plt.rcParams["figure.figsize"] = (12,8)
plt.plot(yxgb_pred,label='XGBoost_Regression_Predictions')
plt.plot(y_test,label='Actual Sales')
plt.legend(loc="upper left")
plt.show()
rmse_xgb=sqrt(mean_squared_error(y_test, yxgb_pred))
print("Mean Squared Error for XG Boost Model is:",rmse_xgb)
# Out:
# [05:24:53] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/objective/regression_obj.cu:213: reg:linear is now deprecated in favor of reg:squarederror.
# Mean Squared Error for XG Boost Model is: 21039.49274023751

# %%
from sklearn.metrics import mean_absolute_error as mae
mae_xgb = mae(y_test,yxgb_pred)
print('Mean Absolute Error for XG Boost Regression Model is:',mae_xgb)
# Out:
# Mean Absolute Error for XG Boost Regression Model is: 15967.951919270834

# %%
import pandas as pd
#AR,MA,ARMA,ARIMA,SARIMA
Billwise_sales = pd.read_csv("Billwise-Sales-Report-2019-2022.csv")
Billwise_sales['DATE'] = pd.to_datetime(Billwise_sales['DATE'], format = "%d/%m/%Y")
Billwise_sales['TIME'] = pd.to_datetime(Billwise_sales['TIME'],format="%I:%M%p").dt.strftime('%H:%M')
Billwise_sales['month_year'] = pd.to_datetime(Billwise_sales['DATE']).dt.to_period('M')
Billwise_sales['Hour'] = pd.to_datetime(Billwise_sales['TIME']).dt.hour
Billwise_sales
# Out:
#         TIME       DATE       BILL_NO                  CONSUMER_NAME  \
# 0      21:12 2022-09-30  AA/2223/7106                   Praveen Kphb
# 1      21:11 2022-09-30  AA/2223/7105                   Praveen Kphb
# 2      20:43 2022-09-30  AA/2223/7104                          Guest
# 3      20:15 2022-09-30  AA/2223/7103       Venkata Ratnam 6th Phase
# 4      20:08 2022-09-30  AA/2223/7102  Raghavendra Vivekananda Nagar
# ...      ...        ...           ...                            ...
# 51732  13:55 2019-01-01     A-A000128                         ravi l
# 51733  13:48 2019-01-01     A-A000127                         balaji
# 51734  13:40 2019-01-01     A-A000126                           ramu
# 51735  13:37 2019-01-01     A-A000125                          ratna
# 51736  13:29 2019-01-01     A-A000124              Ramesh Hydernagar
#
#        Taxable_Amount_0%  Taxable_Amount_5%  Taxable_Amount_12%  \
# 0                    0.0              0.000               0.000
# 1                  225.0            219.048               0.000
# 2                    0.0              0.000               0.000
# 3                    0.0            791.398               0.000
# 4                    0.0            380.952             410.714
# ...                  ...                ...                 ...
# 51732              205.0              0.000               0.000
# 51733              880.0              0.000               0.000
# 51734              225.0              0.000               0.000
# 51735              390.0              0.000               0.000
# 51736              770.0              0.000               0.000
#
#        Taxable_Amount_18%     CGST     SGST  TOTAL_TAX_AMOUNT  \
# 0                9745.763  877.119  877.119          1754.237
# 1                 177.966   21.493   21.493            42.986
# 2               10169.492  915.254  915.254          1830.508
# 3                  75.451   26.576   26.576            53.151
# 4                   0.000   34.167   34.167            68.333
# ...                   ...      ...      ...               ...
# 51732               0.000    0.000    0.000             0.000
# 51733               0.000    0.000    0.000             0.000
# 51734               0.000    0.000    0.000             0.000
# 51735               0.000    0.000    0.000             0.000
# 51736               0.000    0.000    0.000             0.000
#
#        TOTAL_BILL_VALUE  TOTAL_NOOF_ITEMS_PURCHASED PAYMENT_TYPE  \
# 0               11500.0                           1        Paytm
# 1                 665.0                           6        Paytm
# 2               12000.0                           1        Paytm
# 3                 920.0                           5         Cash
# 4                 860.0                           7         Card
# ...                 ...                         ...          ...
# 51732             205.0                           4         Card
# 51733             880.0                           7       Credit
# 51734             225.0                           1         Card
# 51735             390.0                           3         Cash
# 51736             770.0                           5         Card
#
#       ONLINE/OFFLINE month_year  Hour
# 0             Online    2022-09    21
# 1             Online    2022-09    21
# 2             Online    2022-09    20
# 3            Offline    2022-09    20
# 4             Online    2022-09    20
# ...              ...        ...   ...
# 51732         Online    2019-01    13
# 51733         Online    2019-01    13
# 51734         Online    2019-01    13
# 51735        Offline    2019-01    13
# 51736         Online    2019-01    13
#
# [51737 rows x 17 columns]

# %%
sorted_df3 = Billwise_sales.groupby('DATE')['TOTAL_BILL_VALUE'].sum().reset_index()
sorted_df3 = sorted_df3.set_index('DATE')
sorted_df3
# Out:
#             TOTAL_BILL_VALUE
# DATE
# 2019-01-01           37420.0
# 2019-01-02           36140.0
# 2019-01-03           33921.0
# 2019-01-04           45510.0
# 2019-01-05           31980.0
# ...                      ...
# 2022-09-26           26845.0
# 2022-09-27           29009.0
# 2022-09-28           56172.0
# 2022-09-29           36421.0
# 2022-09-30           89272.0
#
# [1361 rows x 1 columns]

# %%
import matplotlib.pyplot as plt
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(sorted_df3['TOTAL_BILL_VALUE']).set_xlim([0, 1000])
plt.show()

# %%
import statsmodels.api as sm
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(sorted_df3['TOTAL_BILL_VALUE'].iloc[13:],lags=25,ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(sorted_df3['TOTAL_BILL_VALUE'].iloc[13:],lags=25,ax=ax2)
# Out:
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
#from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
#pacf = plot_pacf(sorted_df3['TOTAL_BILL_VALUE'],lags=25)
#acf = plot_acf(sorted_df3['TOTAL_BILL_VALUE'],lags=25)

# %%
#split Dataset into train and test 
train = sorted_df3['TOTAL_BILL_VALUE'][:len(sorted_df3)-30]
test = sorted_df3['TOTAL_BILL_VALUE'][len(sorted_df3)-30:]

# %%
from statsmodels.tsa.ar_model import AutoReg
model = AutoReg(train,lags=3).fit()
# Out:
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
print(model.summary())
# Out:
#                             AutoReg Model Results
# ==============================================================================
# Dep. Variable:       TOTAL_BILL_VALUE   No. Observations:                 1331
# Model:                     AutoReg(3)   Log Likelihood              -14937.970
# Method:               Conditional MLE   S.D. of innovations          18574.281
# Date:                Fri, 09 Dec 2022   AIC                          29885.941
# Time:                        05:25:08   BIC                          29911.898
# Sample:                             3   HQIC                         29895.670
#                                  1331
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                2.148e+04   1431.881     15.002      0.000    1.87e+04    2.43e+04
# TOTAL_BILL_VALUE.L1     0.3320      0.027     12.077      0.000       0.278       0.386
# TOTAL_BILL_VALUE.L2     0.0589      0.029      2.037      0.042       0.002       0.116
# TOTAL_BILL_VALUE.L3     0.0485      0.028      1.761      0.078      -0.005       0.102
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.7284           -0.0000j            1.7284           -0.0000
# AR.2           -1.4717           -3.1255j            3.4547           -0.3200
# AR.3           -1.4717           +3.1255j            3.4547            0.3200
# -----------------------------------------------------------------------------

# %%
print(len(train))
print(len(test))
# Out:
# 1331
# 30

# %%
#Make predictions on test data

# %%
start = len(train)
end = len(sorted_df3)-1
pred = model.predict(start=start,end=end,dynamic=False)
pred.index=sorted_df3.index[start:end+1]
# Out:
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\statsmodels\tsa\deterministic.py:302: UserWarning: Only PeriodIndexes, DatetimeIndexes with a frequency set, RangesIndexes, and Index with a unit increment support extending. The index is set will contain the position relative to the data length.
#   fcast_index = self._extend_index(index, steps, forecast_index)

# %%
from matplotlib import pyplot
pyplot.plot(pred)
pyplot.plot(test,color='red')
print(pred)
# Out:
# DATE
# 2022-09-01    59356.038066
# 2022-09-02    50312.809406
# 2022-09-03    46448.123734
# 2022-09-04    42740.738376
# 2022-09-05    40843.973878
# 2022-09-06    39808.591191
# 2022-09-07    39173.429337
# 2022-09-08    38809.639720
# 2022-09-09    38601.268495
# 2022-09-10    38479.877060
# 2022-09-11    38409.669977
# 2022-09-12    38369.112011
# 2022-09-13    38345.628001
# 2022-09-14    38332.039669
# 2022-09-15    38324.179384
# 2022-09-16    38319.631200
# 2022-09-17    38316.999637
# 2022-09-18    38315.477100
# 2022-09-19    38314.596179
# 2022-09-20    38314.086490
# 2022-09-21    38313.791593
# 2022-09-22    38313.620970
# 2022-09-23    38313.522250
# 2022-09-24    38313.465133
# 2022-09-25    38313.432085
# 2022-09-26    38313.412965
# 2022-09-27    38313.401902
# 2022-09-28    38313.395501
# 2022-09-29    38313.391798
# 2022-09-30    38313.389655
# dtype: float64

# %%
#calculate error:
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse_AR=sqrt(mean_squared_error(pred,test))
print('Mean Squared Error for AR Model is:',rmse_AR)
# Out:
# Mean Squared Error for AR Model is: 21196.820823333055

# %%
from sklearn.metrics import mean_absolute_error as mae
mae_AR = mae(test,pred)
print('Mean Absolute Error for AR Model is:',mae_AR)
# Out:
# Mean Absolute Error for AR Model is: 16121.98369843206

# %%
#MA Model
print(sorted_df3.shape)
train=sorted_df3.iloc[:-30]
test=sorted_df3.iloc[-30:]
print(train.shape,test.shape)
# Out:
# (1361, 1)
# (1331, 1) (30, 1)

# %%
import statsmodels.api as sm
model=sm.tsa.arima.ARIMA(train['TOTAL_BILL_VALUE'],order=(0,0,4))
model=model.fit()
model.summary()
# Out:
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:       TOTAL_BILL_VALUE   No. Observations:                 1331
# Model:                 ARIMA(0, 0, 4)   Log Likelihood              -14975.351
# Date:                Fri, 09 Dec 2022   AIC                          29962.701
# Time:                        05:25:18   BIC                          29993.864
# Sample:                             0   HQIC                         29974.380
#                                - 1331
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.827e+04    934.595     40.944      0.000    3.64e+04    4.01e+04
# ma.L1          0.3365      0.025     13.506      0.000       0.288       0.385
# ma.L2          0.1723      0.030      5.793      0.000       0.114       0.231
# ma.L3          0.0938      0.034      2.773      0.006       0.028       0.160
# ma.L4          0.0227      0.032      0.702      0.482      -0.041       0.086
# sigma2      3.748e+08      0.043   8.71e+09      0.000    3.75e+08    3.75e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               734.84
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.18   Skew:                             1.16
# Prob(H) (two-sided):                  0.09   Kurtosis:                         5.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.38e+27. Standard errors may be unstable.
# """

# %%
#make predictions on test set
start=len(train)
end=len(train)+len(test)-1
pred=model.predict(start=start,end=end,typ='levels')#.rename('ARIMA Predictions')
pred.index=sorted_df3.index[start:end+1]
print(pred)
# Out:
# DATE
# 2022-09-01    59811.909978
# 2022-09-02    49963.168368
# 2022-09-03    43864.908698
# 2022-09-04    39430.019309
# 2022-09-05    38266.005943
# 2022-09-06    38266.005943
# 2022-09-07    38266.005943
# 2022-09-08    38266.005943
# 2022-09-09    38266.005943
# 2022-09-10    38266.005943
# 2022-09-11    38266.005943
# 2022-09-12    38266.005943
# 2022-09-13    38266.005943
# 2022-09-14    38266.005943
# 2022-09-15    38266.005943
# 2022-09-16    38266.005943
# 2022-09-17    38266.005943
# 2022-09-18    38266.005943
# 2022-09-19    38266.005943
# 2022-09-20    38266.005943
# 2022-09-21    38266.005943
# 2022-09-22    38266.005943
# 2022-09-23    38266.005943
# 2022-09-24    38266.005943
# 2022-09-25    38266.005943
# 2022-09-26    38266.005943
# 2022-09-27    38266.005943
# 2022-09-28    38266.005943
# 2022-09-29    38266.005943
# 2022-09-30    38266.005943
# Name: predicted_mean, dtype: float64
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
pred.plot(legend=True)
test['TOTAL_BILL_VALUE'].plot(legend=True)
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
test['TOTAL_BILL_VALUE'].mean()
rmse_MA=sqrt(mean_squared_error(pred,test['TOTAL_BILL_VALUE']))
print('Mean Squared Error for MA Model is:',rmse_MA)
# Out:
# Mean Squared Error for MA Model is: 21415.826489972504

# %%
from sklearn.metrics import mean_absolute_error as mae
mae_ma = mae(test['TOTAL_BILL_VALUE'],pred)
print('Mean Absolute Error for MA Model is:',mae_ma)
# Out:
# Mean Absolute Error for MA Model is: 16417.212182975705

# %%
#Make future date predictions uding MA model

# %%
import statsmodels.api as sm
model2=sm.tsa.arima.ARIMA(sorted_df3['TOTAL_BILL_VALUE'],order=(0,0,4))
model2=model2.fit()
model2.summary()
# Out:
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:       TOTAL_BILL_VALUE   No. Observations:                 1361
# Model:                 ARIMA(0, 0, 4)   Log Likelihood              -15316.773
# Date:                Fri, 09 Dec 2022   AIC                          30645.545
# Time:                        05:25:25   BIC                          30676.841
# Sample:                             0   HQIC                         30657.261
#                                - 1361
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.845e+04    919.784     41.808      0.000    3.67e+04    4.03e+04
# ma.L1          0.3307      0.025     13.422      0.000       0.282       0.379
# ma.L2          0.1708      0.029      5.826      0.000       0.113       0.228
# ma.L3          0.0988      0.033      2.994      0.003       0.034       0.163
# ma.L4          0.0192      0.032      0.606      0.545      -0.043       0.082
# sigma2      3.755e+08      0.042   8.99e+09      0.000    3.75e+08    3.75e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):               711.18
# Prob(Q):                              1.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.17   Skew:                             1.15
# Prob(H) (two-sided):                  0.09   Kurtosis:                         5.69
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.91e+24. Standard errors may be unstable.
# """

# %%
#For Future Dates
index_future_dates=pd.date_range(start='2022-10-01',end='2022-10-31')
#print(index_future_dates)
pred=model2.predict(start=len(sorted_df3)+1,end=len(sorted_df3)+31,typ='levels').rename('MA Predictions')
#print(comp_pred)
pred.index=index_future_dates
print(pred)
# Out:
# 2022-10-01    46934.320156
# 2022-10-02    43340.448991
# 2022-10-03    39426.778539
# 2022-10-04    38454.405121
# 2022-10-05    38454.405121
# 2022-10-06    38454.405121
# 2022-10-07    38454.405121
# 2022-10-08    38454.405121
# 2022-10-09    38454.405121
# 2022-10-10    38454.405121
# 2022-10-11    38454.405121
# 2022-10-12    38454.405121
# 2022-10-13    38454.405121
# 2022-10-14    38454.405121
# 2022-10-15    38454.405121
# 2022-10-16    38454.405121
# 2022-10-17    38454.405121
# 2022-10-18    38454.405121
# 2022-10-19    38454.405121
# 2022-10-20    38454.405121
# 2022-10-21    38454.405121
# 2022-10-22    38454.405121
# 2022-10-23    38454.405121
# 2022-10-24    38454.405121
# 2022-10-25    38454.405121
# 2022-10-26    38454.405121
# 2022-10-27    38454.405121
# 2022-10-28    38454.405121
# 2022-10-29    38454.405121
# 2022-10-30    38454.405121
# 2022-10-31    38454.405121
# Freq: D, Name: MA Predictions, dtype: float64
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
#pred.plot(figsize=(12,5),legend=True)
#sorted_df3['TOTAL_BILL_VALUE'].plot(legend=True)

# %%
# !pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\users\bharathi kondaveeti\anaconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy>=1.17 in c:\users\bharathi kondaveeti\anaconda3\lib\site-packages (from statsmodels) (1.22.4)
# Requirement already satisfied: pandas>=0.25 in c:\users\bharathi kondaveeti\anaconda3\lib\site-packages (from statsmodels) (1.3.4)
# Requirement already satisfied: packaging>=21.3 in c:\users\bharathi kondaveeti\anaconda3\lib\site-packages (from statsmodels) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in c:\users\bharathi kondaveeti\anaconda3\lib\site-packages (from statsmodels) (0.5.2)
# Requirement already satisfied: scipy>=1.3 in c:\users\bharathi kondaveeti\anaconda3\lib\site-packages (from statsmodels) (1.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\bharathi kondaveeti\anaconda3\lib\site-packages (from packaging>=21.3->statsmodels) (3.0.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\bharathi kondaveeti\anaconda3\lib\site-packages (from pandas>=0.25->statsmodels) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in c:\users\bharathi kondaveeti\anaconda3\lib\site-packages (from pandas>=0.25->statsmodels) (2021.3)
# Requirement already satisfied: six in c:\users\bharathi kondaveeti\anaconda3\lib\site-packages (from patsy>=0.5.2->statsmodels) (1.16.0)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\bharathi kondaveeti\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\bharathi kondaveeti\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\bharathi kondaveeti\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\bharathi kondaveeti\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\bharathi kondaveeti\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -tatsmodels (c:\users\bharathi kondaveeti\anaconda3\lib\site-packages)

# %%
#ARMA modeL:
import statsmodels.api as sm
ARMA_model=sm.tsa.arima.ARIMA(train['TOTAL_BILL_VALUE'],order=(3,0,4))
ARMA_model=ARMA_model.fit()
ARMA_model.summary()
# Out:
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:       TOTAL_BILL_VALUE   No. Observations:                 1331
# Model:                 ARIMA(3, 0, 4)   Log Likelihood              -14897.545
# Date:                Fri, 09 Dec 2022   AIC                          29813.089
# Time:                        05:25:35   BIC                          29859.833
# Sample:                             0   HQIC                         29830.607
#                                - 1331
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       3.827e+04   2193.680     17.444      0.000     3.4e+04    4.26e+04
# ar.L1          2.1984      0.018    122.300      0.000       2.163       2.234
# ar.L2         -2.1751      0.025    -88.101      0.000      -2.223      -2.127
# ar.L3          0.9464      0.018     52.629      0.000       0.911       0.982
# ma.L1         -1.9541      0.030    -65.512      0.000      -2.013      -1.896
# ma.L2          1.7499      0.053     33.264      0.000       1.647       1.853
# ma.L3         -0.5838      0.052    -11.257      0.000      -0.685      -0.482
# ma.L4         -0.0890      0.028     -3.153      0.002      -0.144      -0.034
# sigma2      3.205e+08      0.277   1.16e+09      0.000    3.21e+08    3.21e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.01   Jarque-Bera (JB):               915.22
# Prob(Q):                              0.94   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.30   Skew:                             1.15
# Prob(H) (two-sided):                  0.01   Kurtosis:                         6.35
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 3.47e+23. Standard errors may be unstable.
# """

# %%
#make predictions on test set
start=len(train)
end=len(train)+len(test)-1
pred=ARMA_model.predict(start=start,end=end,typ='levels')
pred.index=sorted_df3.index[start:end+1]
print(pred)
# Out:
# DATE
# 2022-09-01    51589.910817
# 2022-09-02    47987.155821
# 2022-09-03    50500.238481
# 2022-09-04    51463.204230
# 2022-09-05    49868.020902
# 2022-09-06    46645.145929
# 2022-09-07    43941.129061
# 2022-09-08    43497.018538
# 2022-09-09    45351.956476
# 2022-09-10    47836.615926
# 2022-09-11    48843.843448
# 2022-09-12    47409.318758
# 2022-09-13    44416.455451
# 2022-09-14    41910.531533
# 2022-09-15    41553.657390
# 2022-09-16    43387.191975
# 2022-09-17    45822.532010
# 2022-09-18    46850.453461
# 2022-09-19    45548.437917
# 2022-09-20    42755.189016
# 2022-09-21    40419.456341
# 2022-09-22    40127.955876
# 2022-09-23    41923.944960
# 2022-09-24    44295.625783
# 2022-09-25    45327.136388
# 2022-09-26    44135.940575
# 2022-09-27    41518.257808
# 2022-09-28    39330.837590
# 2022-09-29    39088.393028
# 2022-09-30    40835.792651
# Name: predicted_mean, dtype: float64
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
from matplotlib import pyplot
pyplot.plot(pred,color='black')
pyplot.plot(test,color='red')

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
test['TOTAL_BILL_VALUE'].mean()
rmse_ARIMA=sqrt(mean_squared_error(pred,test['TOTAL_BILL_VALUE']))
print('Mean Squared Error for ARIMA Model is:',rmse_ARIMA)
mae_ARIMA = mae(test['TOTAL_BILL_VALUE'],pred)
print('Mean Absolute Error for ARIMA Model is:',mae_ARIMA)
# Out:
# Mean Squared Error for ARIMA Model is: 19722.18422951012
# Mean Absolute Error for ARIMA Model is: 16501.99637979555

# %%
#Make Future predictions:
#index_future_dates=pd.date_range(start='2022-10-01',end='2022-10-31')

start = len(sorted_df3)+1
end = len(sorted_df3)+31
print('The Future predictions for next month')
pred_future = ARMA_model.predict(start=len(sorted_df3)+1,end=len(sorted_df3)+31,dynamic=False)

pred_future.index=index_future_dates
print(len(pred_future))
# Out:
# The Future predictions for next month
# 31
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
pred_future
# Out:
# 2022-10-01    44157.131377
# 2022-10-02    43059.932339
# 2022-10-03    40598.580722
# 2022-10-04    38542.147312
# 2022-10-05    38336.586724
# 2022-10-06    40028.118932
# 2022-10-07    42247.574196
# 2022-10-08    43252.974864
# 2022-10-09    42236.621732
# 2022-10-10    39916.027229
# 2022-10-11    37976.705961
# 2022-10-12    37798.956381
# 2022-10-13    39430.114480
# 2022-10-14    41567.191851
# 2022-10-15    42549.135408
# 2022-10-16    41603.253940
# 2022-10-17    39410.638204
# 2022-10-18    37577.178487
# 2022-10-19    37420.482620
# 2022-10-20    38988.788908
# 2022-10-21    41042.091390
# 2022-10-22    41996.500738
# 2022-10-23    41112.821667
# 2022-10-24    39037.551778
# 2022-10-25    37300.706315
# 2022-10-26    37160.036535
# 2022-10-27    38664.488881
# 2022-10-28    40633.997116
# 2022-10-29    41558.251185
# 2022-10-30    40730.106159
# 2022-10-31    38763.205419
# Freq: D, Name: predicted_mean, dtype: float64

# %%
from matplotlib import pyplot
pyplot.plot(pred_future,color='red')

# %%
#from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
pacf = plot_pacf(sorted_df3['TOTAL_BILL_VALUE'],lags=25)
acf = plot_acf(sorted_df3['TOTAL_BILL_VALUE'],lags=25)
# Out:
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
#Seasonal ARIMA
import statsmodels.api as sm
model1=sm.tsa.statespace.SARIMAX(train['TOTAL_BILL_VALUE'],order=(3,0,5),seasonal_order=(0,0,0,12))
SARIMA_results1=model1.fit()
SARIMA_results1.summary()
start=len(train)
end=len(train)+len(test)-1
s_pred1=SARIMA_results1.predict(start=start,end=end,typ='levels')#.rename('ARIMA Predictions')
s_pred1.index=sorted_df3.index[start:end+1]
print(s_pred1)

test['TOTAL_BILL_VALUE'].plot()
s_pred1.plot()
# Out:
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# DATE
# 2022-09-01    52051.846086
# 2022-09-02    48214.139515
# 2022-09-03    51277.422881
# 2022-09-04    53026.774277
# 2022-09-05    51139.206810
# 2022-09-06    47053.880839
# 2022-09-07    43846.644628
# 2022-09-08    43912.013536
# 2022-09-09    47173.298336
# 2022-09-10    51158.648782
# 2022-09-11    52871.997771
# 2022-09-12    51042.923068
# 2022-09-13    47066.029764
# 2022-09-14    43935.509228
# 2022-09-15    43988.608896
# 2022-09-16    47158.506901
# 2022-09-17    51042.454730
# 2022-09-18    52720.476260
# 2022-09-19    50948.137330
# 2022-09-20    47076.823108
# 2022-09-21    44021.215418
# 2022-09-22    44062.637325
# 2022-09-23    47143.672956
# 2022-09-24    50928.768650
# 2022-09-25    52572.127162
# 2022-09-26    50854.818484
# 2022-09-27    47086.304156
# 2022-09-28    44103.847865
# 2022-09-29    44134.161086
# 2022-09-30    47128.789849
# Name: predicted_mean, dtype: float64
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# <AxesSubplot:xlabel='DATE'>

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
test['TOTAL_BILL_VALUE'].mean()
rmse_SARIMA1=sqrt(mean_squared_error(s_pred1,test['TOTAL_BILL_VALUE']))
print('Mean Squared Error for SARIMA Model is:',rmse_SARIMA1)
mae_SARIMA1 = mae(test['TOTAL_BILL_VALUE'],s_pred1)
print('Mean Absolute Error for SARIMA Model is:',mae_SARIMA1)
# Out:
# Mean Squared Error for SARIMA Model is: 19165.862102694125
# Mean Absolute Error for SARIMA Model is: 17114.041203049743

# %%
#Seasonal ARIMA
import statsmodels.api as sm
model=sm.tsa.statespace.SARIMAX(train['TOTAL_BILL_VALUE'],order=(3,0,5),seasonal_order=(1,0,1,12))
SARIMA_results=model.fit()
SARIMA_results.summary()
# Out:
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                       SARIMAX Results
# ============================================================================================
# Dep. Variable:                     TOTAL_BILL_VALUE   No. Observations:                 1331
# Model:             SARIMAX(3, 0, 5)x(1, 0, [1], 12)   Log Likelihood              -14908.928
# Date:                              Fri, 09 Dec 2022   AIC                          29839.855
# Time:                                      05:25:52   BIC                          29896.986
# Sample:                                           0   HQIC                         29861.266
#                                              - 1331
# Covariance Type:                                opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          2.2435      0.004    505.668      0.000       2.235       2.252
# ar.L2         -2.2369      0.008   -283.744      0.000      -2.252      -2.221
# ar.L3          0.9934      0.004    224.271      0.000       0.985       1.002
# ma.L1         -1.9929      0.024    -81.683      0.000      -2.041      -1.945
# ma.L2          1.7886      0.056     32.164      0.000       1.680       1.898
# ma.L3         -0.6237      0.073     -8.499      0.000      -0.768      -0.480
# ma.L4         -0.0760      0.061     -1.237      0.216      -0.196       0.044
# ma.L5         -0.0300      0.028     -1.068      0.286      -0.085       0.025
# ar.S.L12       0.9333      0.120      7.752      0.000       0.697       1.169
# ma.S.L12      -0.9441      0.109     -8.631      0.000      -1.159      -0.730
# sigma2      3.318e+08   7.13e-10   4.65e+17      0.000    3.32e+08    3.32e+08
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.02   Jarque-Bera (JB):               799.59
# Prob(Q):                              0.89   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.28   Skew:                             1.06
# Prob(H) (two-sided):                  0.01   Kurtosis:                         6.15
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# [2] Covariance matrix is singular or near-singular, with condition number 1.79e+33. Standard errors may be unstable.
# """

# %%
test
start=len(train)
end=len(train)+len(test)-1
s_pred=SARIMA_results.predict(start=start,end=end,typ='levels')#.rename('ARIMA Predictions')
s_pred.index=sorted_df3.index[start:end+1]
print(s_pred)
# Out:
# DATE
# 2022-09-01    53005.242009
# 2022-09-02    47645.644859
# 2022-09-03    50966.308663
# 2022-09-04    52788.334001
# 2022-09-05    50483.044813
# 2022-09-06    46786.057954
# 2022-09-07    43164.416986
# 2022-09-08    43088.923015
# 2022-09-09    46300.326571
# 2022-09-10    50568.609295
# 2022-09-11    52120.021794
# 2022-09-12    49541.795149
# 2022-09-13    46773.345796
# 2022-09-14    42464.444717
# 2022-09-15    43243.683715
# 2022-09-16    46539.080291
# 2022-09-17    50316.524060
# 2022-09-18    52654.645702
# 2022-09-19    50582.852307
# 2022-09-20    46388.697388
# 2022-09-21    42957.924619
# 2022-09-22    43044.269479
# 2022-09-23    46031.245939
# 2022-09-24    49410.354850
# 2022-09-25    52491.987879
# 2022-09-26    49768.363978
# 2022-09-27    46481.261510
# 2022-09-28    43275.186304
# 2022-09-29    42976.762433
# 2022-09-30    46643.818324
# Name: predicted_mean, dtype: float64
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
residuals=test['TOTAL_BILL_VALUE']-s_pred
residuals
# Out:
# DATE
# 2022-09-01   -18478.242009
# 2022-09-02    17417.355141
# 2022-09-03     6943.691337
# 2022-09-04     3592.665999
# 2022-09-05    10254.955187
# 2022-09-06    -6366.057954
# 2022-09-07   -25378.416986
# 2022-09-08   -12365.923015
# 2022-09-09   -22641.326571
# 2022-09-10   -12893.609295
# 2022-09-11    -9177.021794
# 2022-09-12   -12578.795149
# 2022-09-13   -19995.885796
# 2022-09-14    33401.555283
# 2022-09-15    26482.316285
# 2022-09-16    -9471.080291
# 2022-09-17    26121.475940
# 2022-09-18    11296.354298
# 2022-09-19    16455.147693
# 2022-09-20   -15909.697388
# 2022-09-21   -13945.924619
# 2022-09-22   -12739.269479
# 2022-09-23   -15800.245939
# 2022-09-24   -10495.354850
# 2022-09-25    33586.012121
# 2022-09-26   -22923.363978
# 2022-09-27   -17472.261510
# 2022-09-28    12896.813696
# 2022-09-29    -6555.762433
# 2022-09-30    42628.181676
# dtype: float64

# %%
s_pred.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
SARIMA_results.resid.plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
test['Predicted_SARIMA']=s_pred
# Out:
# C:\Users\BHARAT~1\AppData\Local\Temp/ipykernel_18472/3312833460.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predicted_SARIMA']=s_pred

# %%
test[['TOTAL_BILL_VALUE','Predicted_SARIMA']].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
test['TOTAL_BILL_VALUE'].mean()
rmse_SARIMA=sqrt(mean_squared_error(s_pred,test['TOTAL_BILL_VALUE']))
print('Mean Squared Error for SARIMA Model is:',rmse_SARIMA)
mae_SARIMA = mae(test['TOTAL_BILL_VALUE'],s_pred)
print('Mean Absolute Error for SARIMA Model is:',mae_SARIMA)
# Out:
# Mean Squared Error for SARIMA Model is: 19071.87378334275
# Mean Absolute Error for SARIMA Model is: 16875.492123665277

# %%
#Make Future predictions:
#index_future_dates=pd.date_range(start='2022-10-01',end='2022-10-31')

start = len(sorted_df3)+1
end = len(sorted_df3)+31
print('The Future predictions using SARIMA for next month')
pred_future1 = SARIMA_results.predict(start=len(sorted_df3)+1,end=len(sorted_df3)+31,dynamic=False)
pred_future1.index=index_future_dates
pred_future1
# Out:
# The Future predictions using SARIMA for next month
# C:\Users\Bharathi Kondaveeti\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# 2022-10-01    51985.872011
# 2022-10-02    50071.171804
# 2022-10-03    46243.921687
# 2022-10-04    42893.036269
# 2022-10-05    42294.896890
# 2022-10-06    46603.371493
# 2022-10-07    49569.727710
# 2022-10-08    51928.718052
# 2022-10-09    50212.893263
# 2022-10-10    46130.334246
# 2022-10-11    43554.004607
# 2022-10-12    43336.937883
# 2022-10-13    46240.169694
# 2022-10-14    49827.884233
# 2022-10-15    51567.160121
# 2022-10-16    49705.161932
# 2022-10-17    45444.008390
# 2022-10-18    43603.024717
# 2022-10-19    42759.999293
# 2022-10-20    46293.817197
# 2022-10-21    49936.711086
# 2022-10-22    51324.510253
# 2022-10-23    50174.206609
# 2022-10-24    46367.237369
# 2022-10-25    43348.396721
# 2022-10-26    43153.607435
# 2022-10-27    46061.239799
# 2022-10-28    49440.383170
# 2022-10-29    50550.653243
# 2022-10-30    50075.289646
# 2022-10-31    45780.111106
# Freq: D, Name: predicted_mean, dtype: float64

# %%
#LSTM,BILSTM,GRU PVS STORE

# %%
sorted_df3['TOTAL_BILL_VALUE'].plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
sorted_df3[:200].plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
train = sorted_df3.iloc[:1200]
test = sorted_df3.iloc[1200:]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
scaler.fit(train)
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
scaled_train[:10]
# Out:
# array([[0.26216403],
#        [0.25306012],
#        [0.23727765],
#        [0.31970355],
#        [0.22347243],
#        [0.40809679],
#        [0.20855767],
#        [0.13805219],
#        [0.1080662 ],
#        [0.16168678]])

# %%
from keras.preprocessing.sequence import TimeseriesGenerator
# define generator
n_input = 3
n_features = 1
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
X,y = generator[0]
print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')
# Out:
# Given the Array:
# [0.26216403 0.25306012 0.23727765]
# Predict this y:
#  [[0.31970355]]

# %%
# We do the same thing, but now instead for 1 months
n_input = 30
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# define model
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(n_input, n_features)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100)               40800
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 40,901
# Trainable params: 40,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
model.fit(generator,epochs=50)
# Out:
# Epoch 1/50
# 1170/1170 [==============================] - 21s 16ms/step - loss: 0.0196
# Epoch 2/50
# 1170/1170 [==============================] - 21s 18ms/step - loss: 0.0182
# Epoch 3/50
# 1170/1170 [==============================] - 19s 17ms/step - loss: 0.0180
# Epoch 4/50
# 1170/1170 [==============================] - 20s 17ms/step - loss: 0.0176
# Epoch 5/50
# 1170/1170 [==============================] - 19s 16ms/step - loss: 0.0174
# Epoch 6/50
# 1170/1170 [==============================] - 20s 17ms/step - loss: 0.0175
# Epoch 7/50
# 1170/1170 [==============================] - 19s 16ms/step - loss: 0.0174
# Epoch 8/50
# 1170/1170 [==============================] - 19s 16ms/step - loss: 0.0172
# Epoch 9/50
# 1170/1170 [==============================] - 18s 15ms/step - loss: 0.0173
# Epoch 10/50
# 1170/1170 [==============================] - 19s 16ms/step - loss: 0.0171
# Epoch 11/50
# 1170/1170 [==============================] - 19s 16ms/step - loss: 0.0169
# Epoch 12/50
# 1170/1170 [==============================] - 19s 16ms/step - loss: 0.0165
# Epoch 13/50
# 1170/1170 [==============================] - 18s 16ms/step - loss: 0.0161
# Epoch 14/50
# 1170/1170 [==============================] - 18s 15ms/step - loss: 0.0162
# Epoch 15/50
# 1170/1170 [==============================] - 19s 16ms/step - loss: 0.0161
# Epoch 16/50
# 1170/1170 [==============================] - 19s 16ms/step - loss: 0.0162
# Epoch 17/50
# 1170/1170 [==============================] - 17s 14ms/step - loss: 0.0162
# Epoch 18/50
# 1170/1170 [==============================] - 19s 16ms/step - loss: 0.0162
# Epoch 19/50
# 1170/1170 [==============================] - 17s 15ms/step - loss: 0.0160
# Epoch 20/50
# 1170/1170 [==============================] - 19s 16ms/step - loss: 0.0159
# Epoch 21/50
# 1170/1170 [==============================] - 19s 16ms/step - loss: 0.0160
# Epoch 22/50
# 1170/1170 [==============================] - 18s 16ms/step - loss: 0.0160
# Epoch 23/50
# 1170/1170 [==============================] - 18s 15ms/step - loss: 0.0159
# Epoch 24/50
# 1170/1170 [==============================] - 19s 16ms/step - loss: 0.0158
# Epoch 25/50
# 1170/1170 [==============================] - 18s 16ms/step - loss: 0.0161
# Epoch 26/50
# 1170/1170 [==============================] - 18s 15ms/step - loss: 0.0158
# Epoch 27/50
# 1170/1170 [==============================] - 18s 15ms/step - loss: 0.0156
# Epoch 28/50
# 1170/1170 [==============================] - 18s 15ms/step - loss: 0.0155
# Epoch 29/50
# 1170/1170 [==============================] - 19s 16ms/step - loss: 0.0157
# Epoch 30/50
# 1170/1170 [==============================] - 17s 15ms/step - loss: 0.0158
# Epoch 31/50
# 1170/1170 [==============================] - 18s 16ms/step - loss: 0.0157
# Epoch 32/50
# 1170/1170 [==============================] - 18s 15ms/step - loss: 0.0156
# Epoch 33/50
# 1170/1170 [==============================] - 19s 16ms/step - loss: 0.0156
# Epoch 34/50
# 1170/1170 [==============================] - 18s 16ms/step - loss: 0.0154
# Epoch 35/50
# 1170/1170 [==============================] - 16s 14ms/step - loss: 0.0155
# Epoch 36/50
# 1170/1170 [==============================] - 20s 17ms/step - loss: 0.0154
# Epoch 37/50
# 1170/1170 [==============================] - 19s 17ms/step - loss: 0.0153
# Epoch 38/50
# 1170/1170 [==============================] - 19s 17ms/step - loss: 0.0157
# Epoch 39/50
# 1170/1170 [==============================] - 18s 15ms/step - loss: 0.0153
# Epoch 40/50
# 1170/1170 [==============================] - 18s 16ms/step - loss: 0.0155
# Epoch 41/50
# 1170/1170 [==============================] - 18s 16ms/step - loss: 0.0153
# Epoch 42/50
# 1170/1170 [==============================] - 16s 14ms/step - loss: 0.0154
# Epoch 43/50
# 1170/1170 [==============================] - 20s 17ms/step - loss: 0.0155
# Epoch 44/50
# 1170/1170 [==============================] - 18s 16ms/step - loss: 0.0153
# Epoch 45/50
# 1170/1170 [==============================] - 18s 15ms/step - loss: 0.0153
# Epoch 46/50
# 1170/1170 [==============================] - 18s 15ms/step - loss: 0.0153
# Epoch 47/50
# 1170/1170 [==============================] - 18s 15ms/step - loss: 0.0153
# Epoch 48/50
# 1170/1170 [==============================] - 18s 15ms/step - loss: 0.0151
# Epoch 49/50
# 1170/1170 [==============================] - 18s 15ms/step - loss: 0.0149
# Epoch 50/50
# 1170/1170 [==============================] - 18s 15ms/step - loss: 0.0151

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %%
last_train_batch = scaled_train[-30:]
last_train_batch = last_train_batch.reshape((1, n_input, n_features))

# %%
model.predict(last_train_batch)
# Out:
# 1/1 [==============================] - 0s 419ms/step
# array([[0.27867866]], dtype=float32)

# %%
scaled_test[0]
# Out:
# array([0.48555822])

# %%
test_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(test)):
    
    # get the prediction value for the first batch
    current_pred = model.predict(current_batch)[0]
    
    # append the prediction into the array
    test_predictions.append(current_pred) 
    
    # use the prediction to update the batch and remove the first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 63ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 41ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 61ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 59ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 79ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 39ms/step
# 1/1 [==============================] - 0s 40ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 64ms/step
# 1/1 [==============================] - 0s 68ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 67ms/step
# 1/1 [==============================] - 0s 54ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 52ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 45ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 58ms/step
# 1/1 [==============================] - 0s 47ms/step
# 1/1 [==============================] - 0s 65ms/step
# 1/1 [==============================] - 0s 62ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 48ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 51ms/step
# 1/1 [==============================] - 0s 181ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 49ms/step
# 1/1 [==============================] - 0s 50ms/step
# 1/1 [==============================] - 0s 56ms/step
# 1/1 [==============================] - 0s 53ms/step
# 1/1 [==============================] - 0s 43ms/step
# 1/1 [==============================] - 0s 48ms/step

# %%
test_predictions
# Out:
# [array([0.27867866], dtype=float32),
#  array([0.29612455], dtype=float32),
#  array([0.31466562], dtype=float32),
#  array([0.2963432], dtype=float32),
#  array([0.23815477], dtype=float32),
#  array([0.25574902], dtype=float32),
#  array([0.2747836], dtype=float32),
#  array([0.27833784], dtype=float32),
#  array([0.2954789], dtype=float32),
#  array([0.30141556], dtype=float32),
#  array([0.2802804], dtype=float32),
#  array([0.24983685], dtype=float32),
#  array([0.24969557], dtype=float32),
#  array([0.2660296], dtype=float32),
#  array([0.28829712], dtype=float32),
#  array([0.29830202], dtype=float32),
#  array([0.29621062], dtype=float32),
#  array([0.29444855], dtype=float32),
#  array([0.2591121], dtype=float32),
#  array([0.25205553], dtype=float32),
#  array([0.270851], dtype=float32),
#  array([0.2947923], dtype=float32),
#  array([0.31461686], dtype=float32),
#  array([0.3089062], dtype=float32),
#  array([0.29337355], dtype=float32),
#  array([0.28366423], dtype=float32),
#  array([0.26725078], dtype=float32),
#  array([0.27464846], dtype=float32),
#  array([0.3051144], dtype=float32),
#  array([0.32721263], dtype=float32),
#  array([0.33258656], dtype=float32),
#  array([0.3092162], dtype=float32),
#  array([0.2805493], dtype=float32),
#  array([0.27292636], dtype=float32),
#  array([0.28886706], dtype=float32),
#  array([0.3144775], dtype=float32),
#  array([0.33530432], dtype=float32),
#  array([0.3389573], dtype=float32),
#  array([0.31402865], dtype=float32),
#  array([0.28603685], dtype=float32),
#  array([0.2783699], dtype=float32),
#  array([0.29418355], dtype=float32),
#  array([0.3215232], dtype=float32),
#  array([0.34334666], dtype=float32),
#  array([0.34401673], dtype=float32),
#  array([0.31731653], dtype=float32),
#  array([0.29223555], dtype=float32),
#  array([0.2852396], dtype=float32),
#  array([0.30320182], dtype=float32),
#  array([0.33305573], dtype=float32),
#  array([0.3520261], dtype=float32),
#  array([0.3466537], dtype=float32),
#  array([0.3188569], dtype=float32),
#  array([0.29723954], dtype=float32),
#  array([0.2961731], dtype=float32),
#  array([0.31457046], dtype=float32),
#  array([0.3442701], dtype=float32),
#  array([0.36024472], dtype=float32),
#  array([0.34718716], dtype=float32),
#  array([0.3200267], dtype=float32),
#  array([0.30288664], dtype=float32),
#  array([0.30650577], dtype=float32),
#  array([0.3304533], dtype=float32),
#  array([0.35639048], dtype=float32),
#  array([0.36497098], dtype=float32),
#  array([0.3436727], dtype=float32),
#  array([0.3195352], dtype=float32),
#  array([0.31137165], dtype=float32),
#  array([0.32020783], dtype=float32),
#  array([0.3460193], dtype=float32),
#  array([0.36684453], dtype=float32),
#  array([0.36499786], dtype=float32),
#  array([0.33842015], dtype=float32),
#  array([0.32021835], dtype=float32),
#  array([0.32160896], dtype=float32),
#  array([0.33784038], dtype=float32),
#  array([0.36057985], dtype=float32),
#  array([0.37232962], dtype=float32),
#  array([0.35971618], dtype=float32),
#  array([0.33261576], dtype=float32),
#  array([0.32421643], dtype=float32),
#  array([0.33720052], dtype=float32),
#  array([0.35552776], dtype=float32),
#  array([0.37328458], dtype=float32),
#  array([0.3726064], dtype=float32),
#  array([0.34966552], dtype=float32),
#  array([0.3290692], dtype=float32),
#  array([0.33520186], dtype=float32),
#  array([0.3534997], dtype=float32),
#  array([0.37121478], dtype=float32),
#  array([0.37797785], dtype=float32),
#  array([0.36499876], dtype=float32),
#  array([0.33894917], dtype=float32),
#  array([0.33370757], dtype=float32),
#  array([0.35039586], dtype=float32),
#  array([0.36995757], dtype=float32),
#  array([0.38030615], dtype=float32),
#  array([0.37576842], dtype=float32),
#  array([0.35126358], dtype=float32),
#  array([0.33354157], dtype=float32),
#  array([0.34436923], dtype=float32),
#  array([0.36710218], dtype=float32),
#  array([0.38092247], dtype=float32),
#  array([0.38174507], dtype=float32),
#  array([0.36208963], dtype=float32),
#  array([0.33849534], dtype=float32),
#  array([0.33826363], dtype=float32),
#  array([0.3605442], dtype=float32),
#  array([0.37977296], dtype=float32),
#  array([0.38493282], dtype=float32),
#  array([0.3713146], dtype=float32),
#  array([0.34541923], dtype=float32),
#  array([0.33405933], dtype=float32),
#  array([0.35160103], dtype=float32),
#  array([0.37591392], dtype=float32),
#  array([0.3864481], dtype=float32),
#  array([0.37989876], dtype=float32),
#  array([0.35352486], dtype=float32),
#  array([0.33327594], dtype=float32),
#  array([0.34112057], dtype=float32),
#  array([0.36844438], dtype=float32),
#  array([0.38567716], dtype=float32),
#  array([0.38528955], dtype=float32),
#  array([0.36221313], dtype=float32),
#  array([0.33596897], dtype=float32),
#  array([0.33404073], dtype=float32),
#  array([0.3589912], dtype=float32),
#  array([0.38239986], dtype=float32),
#  array([0.3880949], dtype=float32),
#  array([0.37130284], dtype=float32),
#  array([0.34195456], dtype=float32),
#  array([0.328721], dtype=float32),
#  array([0.34789723], dtype=float32),
#  array([0.3761415], dtype=float32),
#  array([0.3884728], dtype=float32),
#  array([0.38113594], dtype=float32),
#  array([0.35079664], dtype=float32),
#  array([0.32846698], dtype=float32),
#  array([0.33679408], dtype=float32),
#  array([0.36721528], dtype=float32),
#  array([0.3868576], dtype=float32),
#  array([0.38691247], dtype=float32),
#  array([0.36132962], dtype=float32),
#  array([0.33207375], dtype=float32),
#  array([0.32892972], dtype=float32),
#  array([0.35655987], dtype=float32),
#  array([0.38240498], dtype=float32),
#  array([0.389378], dtype=float32),
#  array([0.37209907], dtype=float32),
#  array([0.33962137], dtype=float32),
#  array([0.3240507], dtype=float32),
#  array([0.34484667], dtype=float32),
#  array([0.37566888], dtype=float32),
#  array([0.38890827], dtype=float32),
#  array([0.38291878], dtype=float32),
#  array([0.35021937], dtype=float32),
#  array([0.32464567], dtype=float32),
#  array([0.33326954], dtype=float32),
#  array([0.36567754], dtype=float32),
#  array([0.38658226], dtype=float32),
#  array([0.38818267], dtype=float32)]

# %%
true_predictions = scaler.inverse_transform(test_predictions)

# %%
test['Predictions'] = true_predictions
# Out:
# C:\Users\BHARAT~1\AppData\Local\Temp/ipykernel_18472/4269337381.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions'] = true_predictions

# %%
test
# Out:
#             TOTAL_BILL_VALUE   Predictions
# DATE
# 2022-04-23           68829.0  39741.940302
# 2022-04-24           53264.0  42194.815285
# 2022-04-25           68817.0  44801.670882
# 2022-04-26           45205.0  42225.558612
# 2022-04-27           28968.0  34044.322359
# ...                      ...           ...
# 2022-09-26           26845.0  46204.856313
# 2022-09-27           29009.0  47417.363562
# 2022-09-28           56172.0  51973.895819
# 2022-09-29           36421.0  54913.078522
# 2022-09-30           89272.0  55138.095202
#
# [161 rows x 2 columns]

# %%
test.plot(figsize=(14,5))
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse=sqrt(mean_squared_error(test['TOTAL_BILL_VALUE'],test['Predictions']))
print('Root Mean Square Error for LSTM model:',rmse)
# Out:
# Root Mean Square Error for LSTM model: 18833.94832632073

# %%
mae = mae(test['TOTAL_BILL_VALUE'],test['Predictions'])
print('Mean Absolute Error for LSTM Model is:',mae)
# Out:
# Mean Absolute Error for LSTM Model is: 15686.068979522719

# %%
#Implementing LSTM,BILSTM and GRU in one function

# %%
sorted_df4 = Billwise_sales.groupby(['DATE'])['TOTAL_BILL_VALUE','TOTAL_NOOF_ITEMS_PURCHASED'].sum().reset_index()
sorted_df4=sorted_df4.set_index('DATE')
sorted_df4
# Out:
# C:\Users\BHARAT~1\AppData\Local\Temp/ipykernel_18472/1064734108.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   sorted_df4 = Billwise_sales.groupby(['DATE'])['TOTAL_BILL_VALUE','TOTAL_NOOF_ITEMS_PURCHASED'].sum().reset_index()
#             TOTAL_BILL_VALUE  TOTAL_NOOF_ITEMS_PURCHASED
# DATE
# 2019-01-01           37420.0                         296
# 2019-01-02           36140.0                         245
# 2019-01-03           33921.0                         163
# 2019-01-04           45510.0                         348
# 2019-01-05           31980.0                         224
# ...                      ...                         ...
# 2022-09-26           26845.0                         108
# 2022-09-27           29009.0                         119
# 2022-09-28           56172.0                         168
# 2022-09-29           36421.0                         105
# 2022-09-30           89272.0                         163
#
# [1361 rows x 2 columns]

# %%
# Split train data and test data
train_size = int(len(sorted_df4)*0.8)
train_dataset, test_dataset = sorted_df4.iloc[:train_size],sorted_df4.iloc[train_size:]
# Plot train and test data
plt.figure(figsize = (10, 6))
plt.plot(train_dataset.TOTAL_BILL_VALUE)
plt.plot(test_dataset.TOTAL_BILL_VALUE)
plt.xlabel('Date (day)')
plt.ylabel('Daily Sales')
plt.legend(['Train set', 'Test set'], loc='upper right')
print('Dimension of train data: ',train_dataset.shape)
print('Dimension of test data: ', test_dataset.shape)
# Out:
# Dimension of train data:  (1088, 2)
# Dimension of test data:  (273, 2)

# %%
# Split train data to X and y
X_train = train_dataset.drop('TOTAL_BILL_VALUE', axis = 1)
y_train = train_dataset.loc[:,['TOTAL_BILL_VALUE']]
# Split test data to X and y
X_test = test_dataset.drop('TOTAL_BILL_VALUE', axis = 1)
y_test = test_dataset.loc[:,['TOTAL_BILL_VALUE']]

# %%
from sklearn.preprocessing import MinMaxScaler

# Different scaler for input and output
scaler_x = MinMaxScaler(feature_range = (0,1))
scaler_y = MinMaxScaler(feature_range = (0,1))
# Fit the scaler using available training data
input_scaler = scaler_x.fit(X_train)
output_scaler = scaler_y.fit(y_train)
# Apply the scaler to training data
train_y_norm = output_scaler.transform(y_train)
train_x_norm = input_scaler.transform(X_train)
# Apply the scaler to test data
test_y_norm = output_scaler.transform(y_test)
test_x_norm = input_scaler.transform(X_test)

# %%
# Create a 3D input
import numpy as np
def create_dataset (X, y, time_steps = 1):
    Xs, ys = [], []
    for i in range(len(X)-time_steps):
        v = X[i:i+time_steps, :]
        Xs.append(v)
        ys.append(y[i+time_steps])
    return np.array(Xs), np.array(ys)
TIME_STEPS = 30
X_test, y_test = create_dataset(test_x_norm, test_y_norm,   
                                TIME_STEPS)
X_train, y_train = create_dataset(train_x_norm, train_y_norm, 
                                  TIME_STEPS)
print('X_train.shape: ', X_test.shape)
print('y_train.shape: ', y_train.shape)
print('X_test.shape: ', X_test.shape)
print('y_test.shape: ', y_train.shape)
# Out:
# X_train.shape:  (243, 30, 1)
# y_train.shape:  (1058, 1)
# X_test.shape:  (243, 30, 1)
# y_test.shape:  (1058, 1)

# %%
import scipy
import numpy
import tensorflow as tf
import tensorflow as keras
from tensorflow.keras import Sequential, layers, callbacks
from tensorflow.keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional


# Create BiLSTM model
def create_model_bilstm(units):
    model = Sequential()
    model.add(Bidirectional(LSTM(units = units,                             
              return_sequences=True),
              input_shape=(X_train.shape[1], X_train.shape[2])))
    model.add(Bidirectional(LSTM(units = units)))
    model.add(Dense(1))
    #Compile model
    model.compile(loss='mse', optimizer='adam')
    return model
# Create LSTM or GRU model
def create_model(units, m):
    model = Sequential()
    model.add(m (units = units, return_sequences = True,
                input_shape = [X_train.shape[1], X_train.shape[2]]))
    model.add(Dropout(0.2))
    model.add(m (units = units))
    model.add(Dropout(0.2))
    model.add(Dense(units = 1))
    #Compile model
    model.compile(loss='mse', optimizer='adam')
    return model
# BiLSTM
model_bilstm = create_model_bilstm(64)
# GRU and LSTM
model_gru = create_model(64, GRU)
model_lstm = create_model(64, LSTM)

# %%
# Fit BiLSTM, LSTM and GRU
from keras.callbacks import EarlyStopping, ModelCheckpoint

def fit_model(model):
    early_stop = tf.keras.callbacks.EarlyStopping(monitor = 'val_loss',patience = 10)
    history = model.fit(X_train, y_train, epochs = 100,  
                        validation_split = 0.2, batch_size = 32, 
                        shuffle = False, callbacks = [early_stop])
    return history
history_bilstm = fit_model(model_bilstm)
history_lstm = fit_model(model_lstm)
history_gru = fit_model(model_gru)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 20s 213ms/step - loss: 0.0210 - val_loss: 0.0169
# Epoch 2/100
# 27/27 [==============================] - 2s 76ms/step - loss: 0.0212 - val_loss: 0.0170
# Epoch 3/100
# 27/27 [==============================] - 2s 85ms/step - loss: 0.0205 - val_loss: 0.0171
# Epoch 4/100
# 27/27 [==============================] - 2s 81ms/step - loss: 0.0209 - val_loss: 0.0175
# Epoch 5/100
# 27/27 [==============================] - 2s 79ms/step - loss: 0.0210 - val_loss: 0.0176
# Epoch 6/100
# 27/27 [==============================] - 2s 87ms/step - loss: 0.0211 - val_loss: 0.0193
# Epoch 7/100
# 27/27 [==============================] - 2s 77ms/step - loss: 0.0218 - val_loss: 0.0206
# Epoch 8/100
# 27/27 [==============================] - 2s 77ms/step - loss: 0.0222 - val_loss: 0.0209
# Epoch 9/100
# 27/27 [==============================] - 2s 73ms/step - loss: 0.0224 - val_loss: 0.0205
# Epoch 10/100
# 27/27 [==============================] - 2s 71ms/step - loss: 0.0228 - val_loss: 0.0179
# Epoch 11/100
# 27/27 [==============================] - 2s 70ms/step - loss: 0.0221 - val_loss: 0.0169
# Epoch 12/100
# 27/27 [==============================] - 2s 73ms/step - loss: 0.0210 - val_loss: 0.0168
# Epoch 13/100
# 27/27 [==============================] - 2s 74ms/step - loss: 0.0206 - val_loss: 0.0169
# Epoch 14/100
# 27/27 [==============================] - 2s 74ms/step - loss: 0.0206 - val_loss: 0.0169
# Epoch 15/100
# 27/27 [==============================] - 2s 75ms/step - loss: 0.0206 - val_loss: 0.0169
# Epoch 16/100
# 27/27 [==============================] - 2s 74ms/step - loss: 0.0205 - val_loss: 0.0168
# Epoch 17/100
# 27/27 [==============================] - 2s 76ms/step - loss: 0.0205 - val_loss: 0.0168
# Epoch 18/100
# 27/27 [==============================] - 2s 73ms/step - loss: 0.0204 - val_loss: 0.0168
# Epoch 19/100
# 27/27 [==============================] - 2s 73ms/step - loss: 0.0204 - val_loss: 0.0168
# Epoch 20/100
# 27/27 [==============================] - 2s 79ms/step - loss: 0.0203 - val_loss: 0.0168
# Epoch 21/100
# 27/27 [==============================] - 3s 97ms/step - loss: 0.0202 - val_loss: 0.0167
# Epoch 22/100
# 27/27 [==============================] - 2s 84ms/step - loss: 0.0202 - val_loss: 0.0167
# Epoch 23/100
# 27/27 [==============================] - 3s 94ms/step - loss: 0.0201 - val_loss: 0.0167
# Epoch 24/100
# 27/27 [==============================] - 2s 69ms/step - loss: 0.0201 - val_loss: 0.0166
# Epoch 25/100
# 27/27 [==============================] - 2s 80ms/step - loss: 0.0200 - val_loss: 0.0166
# Epoch 26/100
# 27/27 [==============================] - 2s 68ms/step - loss: 0.0199 - val_loss: 0.0165
# Epoch 27/100
# 27/27 [==============================] - 2s 90ms/step - loss: 0.0198 - val_loss: 0.0165
# Epoch 28/100
# 27/27 [==============================] - 2s 73ms/step - loss: 0.0198 - val_loss: 0.0164
# Epoch 29/100
# 27/27 [==============================] - 2s 65ms/step - loss: 0.0197 - val_loss: 0.0164
# Epoch 30/100
# 27/27 [==============================] - 2s 76ms/step - loss: 0.0196 - val_loss: 0.0163
# Epoch 31/100
# 27/27 [==============================] - 2s 81ms/step - loss: 0.0195 - val_loss: 0.0162
# Epoch 32/100
# 27/27 [==============================] - 2s 73ms/step - loss: 0.0194 - val_loss: 0.0161
# Epoch 33/100
# 27/27 [==============================] - 2s 70ms/step - loss: 0.0195 - val_loss: 0.0160
# Epoch 34/100
# 27/27 [==============================] - 2s 71ms/step - loss: 0.0190 - val_loss: 0.0176
# Epoch 35/100
# 27/27 [==============================] - 2s 83ms/step - loss: 0.0205 - val_loss: 0.0176
# Epoch 36/100
# 27/27 [==============================] - 2s 83ms/step - loss: 0.0205 - val_loss: 0.0165
# Epoch 37/100
# 27/27 [==============================] - 2s 74ms/step - loss: 0.0201 - val_loss: 0.0159
# Epoch 38/100
# 27/27 [==============================] - 2s 70ms/step - loss: 0.0192 - val_loss: 0.0159
# Epoch 39/100
# 27/27 [==============================] - 2s 67ms/step - loss: 0.0196 - val_loss: 0.0156
# Epoch 40/100
# 27/27 [==============================] - 2s 92ms/step - loss: 0.0196 - val_loss: 0.0156
# Epoch 41/100
# 27/27 [==============================] - 2s 73ms/step - loss: 0.0197 - val_loss: 0.0155
# Epoch 42/100
# 27/27 [==============================] - 2s 72ms/step - loss: 0.0190 - val_loss: 0.0155
# Epoch 43/100
# 27/27 [==============================] - 2s 72ms/step - loss: 0.0189 - val_loss: 0.0155
# Epoch 44/100
# 27/27 [==============================] - 2s 66ms/step - loss: 0.0188 - val_loss: 0.0154
# Epoch 45/100
# 27/27 [==============================] - 2s 67ms/step - loss: 0.0187 - val_loss: 0.0154
# Epoch 46/100
# 27/27 [==============================] - 2s 85ms/step - loss: 0.0186 - val_loss: 0.0154
# Epoch 47/100
# 27/27 [==============================] - 2s 80ms/step - loss: 0.0185 - val_loss: 0.0154
# Epoch 48/100
# 27/27 [==============================] - 2s 68ms/step - loss: 0.0184 - val_loss: 0.0153
# Epoch 49/100
# 27/27 [==============================] - 2s 70ms/step - loss: 0.0184 - val_loss: 0.0153
# Epoch 50/100
# 27/27 [==============================] - 2s 84ms/step - loss: 0.0183 - val_loss: 0.0153
# Epoch 51/100
# 27/27 [==============================] - 2s 71ms/step - loss: 0.0183 - val_loss: 0.0153
# Epoch 52/100
# 27/27 [==============================] - 2s 71ms/step - loss: 0.0182 - val_loss: 0.0152
# Epoch 53/100
# 27/27 [==============================] - 2s 68ms/step - loss: 0.0182 - val_loss: 0.0152
# Epoch 54/100
# 27/27 [==============================] - 2s 83ms/step - loss: 0.0182 - val_loss: 0.0152
# Epoch 55/100
# 27/27 [==============================] - 2s 83ms/step - loss: 0.0181 - val_loss: 0.0152
# Epoch 56/100
# 27/27 [==============================] - 2s 82ms/step - loss: 0.0181 - val_loss: 0.0151
# Epoch 57/100
# 27/27 [==============================] - 2s 76ms/step - loss: 0.0181 - val_loss: 0.0151
# Epoch 58/100
# 27/27 [==============================] - 2s 69ms/step - loss: 0.0180 - val_loss: 0.0151
# Epoch 59/100
# 27/27 [==============================] - 2s 86ms/step - loss: 0.0181 - val_loss: 0.0151
# Epoch 60/100
# 27/27 [==============================] - 2s 84ms/step - loss: 0.0212 - val_loss: 0.0157
# Epoch 61/100
# 27/27 [==============================] - 2s 78ms/step - loss: 0.0195 - val_loss: 0.0166
# Epoch 62/100
# 27/27 [==============================] - 2s 76ms/step - loss: 0.0203 - val_loss: 0.0155
# Epoch 63/100
# 27/27 [==============================] - 2s 78ms/step - loss: 0.0196 - val_loss: 0.0152
# Epoch 64/100
# 27/27 [==============================] - 2s 90ms/step - loss: 0.0187 - val_loss: 0.0152
# Epoch 65/100
# 27/27 [==============================] - 2s 71ms/step - loss: 0.0184 - val_loss: 0.0152
# Epoch 66/100
# 27/27 [==============================] - 2s 71ms/step - loss: 0.0184 - val_loss: 0.0152
# Epoch 67/100
# 27/27 [==============================] - 2s 82ms/step - loss: 0.0183 - val_loss: 0.0152
# Epoch 68/100
# 27/27 [==============================] - 2s 84ms/step - loss: 0.0182 - val_loss: 0.0152
# Epoch 1/100
# 27/27 [==============================] - 11s 110ms/step - loss: 0.0212 - val_loss: 0.0178
# Epoch 2/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.0222 - val_loss: 0.0174
# Epoch 3/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.0216 - val_loss: 0.0190
# Epoch 4/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.0226 - val_loss: 0.0208
# Epoch 5/100
# 27/27 [==============================] - 2s 62ms/step - loss: 0.0237 - val_loss: 0.0210
# Epoch 6/100
# 27/27 [==============================] - 1s 50ms/step - loss: 0.0236 - val_loss: 0.0192
# Epoch 7/100
# 27/27 [==============================] - 1s 45ms/step - loss: 0.0237 - val_loss: 0.0173
# Epoch 8/100
# 27/27 [==============================] - 1s 50ms/step - loss: 0.0222 - val_loss: 0.0171
# Epoch 9/100
# 27/27 [==============================] - 1s 47ms/step - loss: 0.0217 - val_loss: 0.0171
# Epoch 10/100
# 27/27 [==============================] - 1s 43ms/step - loss: 0.0215 - val_loss: 0.0171
# Epoch 11/100
# 27/27 [==============================] - 1s 43ms/step - loss: 0.0213 - val_loss: 0.0172
# Epoch 12/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.0212 - val_loss: 0.0172
# Epoch 13/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.0216 - val_loss: 0.0172
# Epoch 14/100
# 27/27 [==============================] - 1s 56ms/step - loss: 0.0215 - val_loss: 0.0172
# Epoch 15/100
# 27/27 [==============================] - 1s 46ms/step - loss: 0.0214 - val_loss: 0.0172
# Epoch 16/100
# 27/27 [==============================] - 1s 46ms/step - loss: 0.0209 - val_loss: 0.0172
# Epoch 17/100
# 27/27 [==============================] - 1s 50ms/step - loss: 0.0213 - val_loss: 0.0172
# Epoch 18/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.0215 - val_loss: 0.0172
# Epoch 1/100
# 27/27 [==============================] - 12s 106ms/step - loss: 0.0220 - val_loss: 0.0206
# Epoch 2/100
# 27/27 [==============================] - 1s 45ms/step - loss: 0.0232 - val_loss: 0.0193
# Epoch 3/100
# 27/27 [==============================] - 1s 43ms/step - loss: 0.0230 - val_loss: 0.0206
# Epoch 4/100
# 27/27 [==============================] - 1s 40ms/step - loss: 0.0235 - val_loss: 0.0193
# Epoch 5/100
# 27/27 [==============================] - 1s 39ms/step - loss: 0.0234 - val_loss: 0.0183
# Epoch 6/100
# 27/27 [==============================] - 1s 53ms/step - loss: 0.0228 - val_loss: 0.0174
# Epoch 7/100
# 27/27 [==============================] - 2s 63ms/step - loss: 0.0222 - val_loss: 0.0171
# Epoch 8/100
# 27/27 [==============================] - 1s 51ms/step - loss: 0.0220 - val_loss: 0.0170
# Epoch 9/100
# 27/27 [==============================] - 1s 51ms/step - loss: 0.0217 - val_loss: 0.0169
# Epoch 10/100
# 27/27 [==============================] - 1s 37ms/step - loss: 0.0212 - val_loss: 0.0167
# Epoch 11/100
# 27/27 [==============================] - 1s 44ms/step - loss: 0.0212 - val_loss: 0.0167
# Epoch 12/100
# 27/27 [==============================] - 1s 52ms/step - loss: 0.0217 - val_loss: 0.0165
# Epoch 13/100
# 27/27 [==============================] - 1s 48ms/step - loss: 0.0210 - val_loss: 0.0165
# Epoch 14/100
# 27/27 [==============================] - 1s 53ms/step - loss: 0.0209 - val_loss: 0.0164
# Epoch 15/100
# 27/27 [==============================] - 2s 59ms/step - loss: 0.0208 - val_loss: 0.0163
# Epoch 16/100
# 27/27 [==============================] - 1s 51ms/step - loss: 0.0207 - val_loss: 0.0163
# Epoch 17/100
# 27/27 [==============================] - 1s 50ms/step - loss: 0.0205 - val_loss: 0.0163
# Epoch 18/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.0206 - val_loss: 0.0162
# Epoch 19/100
# 27/27 [==============================] - 1s 50ms/step - loss: 0.0208 - val_loss: 0.0163
# Epoch 20/100
# 27/27 [==============================] - 1s 53ms/step - loss: 0.0207 - val_loss: 0.0161
# Epoch 21/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.0198 - val_loss: 0.0161
# Epoch 22/100
# 27/27 [==============================] - 1s 52ms/step - loss: 0.0205 - val_loss: 0.0160
# Epoch 23/100
# 27/27 [==============================] - 2s 56ms/step - loss: 0.0204 - val_loss: 0.0159
# Epoch 24/100
# 27/27 [==============================] - 2s 60ms/step - loss: 0.0205 - val_loss: 0.0158
# Epoch 25/100
# 27/27 [==============================] - 2s 58ms/step - loss: 0.0206 - val_loss: 0.0156
# Epoch 26/100
# 27/27 [==============================] - 2s 59ms/step - loss: 0.0193 - val_loss: 0.0156
# Epoch 27/100
# 27/27 [==============================] - 1s 53ms/step - loss: 0.0202 - val_loss: 0.0154
# Epoch 28/100
# 27/27 [==============================] - 2s 56ms/step - loss: 0.0196 - val_loss: 0.0153
# Epoch 29/100
# 27/27 [==============================] - 2s 59ms/step - loss: 0.0197 - val_loss: 0.0153
# Epoch 30/100
# 27/27 [==============================] - 1s 54ms/step - loss: 0.0201 - val_loss: 0.0150
# Epoch 31/100
# 27/27 [==============================] - 2s 56ms/step - loss: 0.0197 - val_loss: 0.0150
# Epoch 32/100
# 27/27 [==============================] - 2s 56ms/step - loss: 0.0196 - val_loss: 0.0150
# Epoch 33/100
# 27/27 [==============================] - 2s 60ms/step - loss: 0.0198 - val_loss: 0.0149
# Epoch 34/100
# 27/27 [==============================] - 2s 57ms/step - loss: 0.0199 - val_loss: 0.0148
# Epoch 35/100
# 27/27 [==============================] - 2s 60ms/step - loss: 0.0194 - val_loss: 0.0148
# Epoch 36/100
# 27/27 [==============================] - 2s 61ms/step - loss: 0.0195 - val_loss: 0.0148
# Epoch 37/100
# 27/27 [==============================] - 2s 60ms/step - loss: 0.0193 - val_loss: 0.0147
# Epoch 38/100
# 27/27 [==============================] - 1s 53ms/step - loss: 0.0194 - val_loss: 0.0147
# Epoch 39/100
# 27/27 [==============================] - 1s 54ms/step - loss: 0.0196 - val_loss: 0.0147
# Epoch 40/100
# 27/27 [==============================] - 2s 57ms/step - loss: 0.0193 - val_loss: 0.0147
# Epoch 41/100
# 27/27 [==============================] - 1s 52ms/step - loss: 0.0200 - val_loss: 0.0146
# Epoch 42/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.0193 - val_loss: 0.0147
# Epoch 43/100
# 27/27 [==============================] - 1s 49ms/step - loss: 0.0189 - val_loss: 0.0146
# Epoch 44/100
# 27/27 [==============================] - 1s 44ms/step - loss: 0.0195 - val_loss: 0.0147
# Epoch 45/100
# 27/27 [==============================] - 1s 39ms/step - loss: 0.0191 - val_loss: 0.0147
# Epoch 46/100
# 27/27 [==============================] - 1s 46ms/step - loss: 0.0192 - val_loss: 0.0147
# Epoch 47/100
# 27/27 [==============================] - 1s 44ms/step - loss: 0.0190 - val_loss: 0.0146
# Epoch 48/100
# 27/27 [==============================] - 1s 41ms/step - loss: 0.0189 - val_loss: 0.0147
# Epoch 49/100
# 27/27 [==============================] - 1s 45ms/step - loss: 0.0190 - val_loss: 0.0147
# Epoch 50/100
# 27/27 [==============================] - 1s 52ms/step - loss: 0.0187 - val_loss: 0.0147
# Epoch 51/100
# 27/27 [==============================] - 1s 53ms/step - loss: 0.0188 - val_loss: 0.0148

# %%
# Plot train loss and validation loss
def plot_loss (history):
    plt.figure(figsize = (10, 6))
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.ylabel('Loss')
    plt.xlabel('epoch')
    plt.legend(['Train loss', 'Validation loss'], loc='upper right')
plot_loss (history_bilstm)
plot_loss (history_lstm)
plot_loss (history_gru)

# %%
y_test = scaler_y.inverse_transform(y_test)
y_train = scaler_y.inverse_transform(y_train)

# %%
# Make prediction
def prediction(model):
    prediction = model.predict(X_test)
    prediction = scaler_y.inverse_transform(prediction)
    return prediction
prediction_bilstm = prediction(model_bilstm)
prediction_lstm = prediction(model_lstm)
prediction_gru = prediction(model_gru)
# Plot true future vs prediction
def plot_future(prediction, y_test):
    plt.figure(figsize=(10, 6))
    range_future = len(prediction)
    plt.plot(np.arange(range_future), np.array(y_test), 
             label='Actuals')     
    plt.plot(np.arange(range_future),np.array(prediction),
            label='Prediction')
    plt.legend(loc='upper left')
    plt.xlabel('Date (day)')
    plt.ylabel('Total Sales')
plot_future(prediction_bilstm, y_test)
plot_future(prediction_lstm, y_test)
plot_future(prediction_gru, y_test)
# Out:
# 8/8 [==============================] - 3s 24ms/step
# 8/8 [==============================] - 2s 16ms/step
# 8/8 [==============================] - 1s 14ms/step

# %%
# Define a function to calculate MAE and RMSE
def evaluate_prediction(predictions, actual, model_name):
    errors = predictions - actual
    mse = np.square(errors).mean()
    rmse = np.sqrt(mse)
    mae = np.abs(errors).mean()
    print(model_name + ':')
    print('Mean Absolute Error: {:.4f}'.format(mae))
    print('Root Mean Square Error: {:.4f}'.format(rmse))
    print('')
evaluate_prediction(prediction_bilstm, y_test, 'Bidirectional LSTM')
evaluate_prediction(prediction_lstm, y_test, 'LSTM')
evaluate_prediction(prediction_gru, y_test, 'GRU')
# Out:
# Bidirectional LSTM:
# Mean Absolute Error: 14077.0693
# Root Mean Square Error: 18510.4314
#
# LSTM:
# Mean Absolute Error: 14354.5267
# Root Mean Square Error: 18728.3099
#
# GRU:
# Mean Absolute Error: 13767.8610
# Root Mean Square Error: 18047.8703
